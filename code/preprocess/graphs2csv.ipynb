# %%
# import 

from collections import defaultdict, OrderedDict, Counter
from datetime import datetime

from dateutil.relativedelta import relativedelta
import glob
from itertools import product, combinations
import matplotlib.pyplot as plt
import numpy    as np
#import networkx as nx
from operator import itemgetter
import pandas   as pd
import rdflib as rdflib
import re
from scipy.signal import convolve2d
import seaborn as sns
from sklearn.preprocessing import MultiLabelBinarizer, minmax_scale
from SPARQLWrapper import SPARQLWrapper, JSON, POST, TURTLE
import sys
from rdflib.namespace import XSD, Namespace
from rdflib.term import URIRef

import IPython
import pprint
pp = pprint.PrettyPrinter(indent=4)



from constants import *
from helpers import *


from rdflib import Graph

from rdflib.namespace import RDF, SKOS
rel = rdflib.Namespace('http://ldf.fi/relse/')

# %%
# helper functions

def to_df(reslist, sort_column):
    my_df=pd.DataFrame(reslist).sort_values(by=sort_column)
    if "year" in my_df.columns:
        my_df["year"]=pd.to_numeric(my_df["year"])
    return my_df


# add period function
def add_period(df_fo, columnname="year"):
    df_fo['period'] = pd.cut(df_fo[columnname], bins=bins, include_lowest=True, precision=0)
    df_fo['period'] = df_fo['period'].astype("str")

    df_fo["period"]=df_fo["period"].apply(lambda x: int(x.split(",")[0].replace("[","")))
    return df_fo

# decade function
def add_decade(df_fi, columname="year"):
    df_fi["decade"]=(df_fi["year"]-1)- ((df_fi["year"]-1)%10)
    
    return df_fi

# %%
# Query

# translated
Q = """
PREFIX rel: <http://ldf.fi/relse/>

CONSTRUCT {


# ?teos a rel:novel ;
    skos:prefLabel ?title ;
    rel:hasPublication ?julkaisu ;
    rel:pubYear ?vuosi_ .

# ?julkaisu a rel:publication ;
    rel:hasPublisher ?publisher ;
    rel:pubYear ?vuosi_ .


# ?publisher a rel:publisher ;
	skos:prefLabel ?publisher_name .

}

WHERE {

  # ?teos a kaunokki:romaani ; skos:prefLabel ?title .
  # ?teos kaunokki:alkukieli ?kieliuri .
  FILTER (?kieliuri !=  <http://lexvo.org/id/iso639-3/fin>  )
  OPTIONAL {?kieliuri skos:prefLabel ?kieli . }
  # ?teos kaunokki:manifests_in ?julkaisu .
  # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> . # käännetty suomeksi
  FILTER EXISTS {?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin>  }
  # ?julkaisu kaunokki:ilmestymisvuosi ?vuosi . ?vuosi skos:prefLabel ?vuosiluku .
  BIND(xsd:integer(?vuosiluku) AS ?vuosi_)
  # ?julkaisu kaunokki:hasPublisher ?publisher .
  OPTIONAL { ?publisher skos:prefLabel ?publisher_name }


} 
"""

# %%
# construct graph

# query graph
print('\n\n*** constructing the graph')
sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")

sparql.setQuery(PREFIXES + Q)

sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])

sparql.setReturnFormat(TURTLE)
results = sparql.query().convert()
# Out:
# *** constructing the graph

# %%
# parse

from rdflib import Graph
g_k = Graph()
#g.parse(data=results, format="turtle") # "mygraph.ttl"
g_k.parse(data=results, format="turtle")
# Out:
# <Graph identifier=N29325a315a60471cbdf71b2169841ef4 (<class 'rdflib.graph.Graph'>)>

# %%
# same for Finnish literature


Q_fi = """
PREFIX rel: <http://ldf.fi/relse/>

CONSTRUCT {


# ?teos a rel:novel ;
    skos:prefLabel ?title ;
    rel:hasPublication ?julkaisu ;
    rel:pubYear ?vuosi_ .

# ?julkaisu a rel:publication ;
    rel:hasPublisher ?publisher ;
    rel:pubYear ?vuosi_ .


# ?publisher a rel:publisher ;
	skos:prefLabel ?publisher_name .

}

WHERE {

  # ?teos a kaunokki:romaani ; skos:prefLabel ?title .
  # ?teos kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin>  .
  #OPTIONAL {?kieliuri skos:prefLabel ?kieli . }
  # ?teos kaunokki:manifests_in ?julkaisu .
  # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> . # käännetty suomeksi
  FILTER EXISTS {?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin>  }
  # ?julkaisu kaunokki:ilmestymisvuosi ?vuosi . ?vuosi skos:prefLabel ?vuosiluku .
  BIND(xsd:integer(?vuosiluku) AS ?vuosi_)
  # ?julkaisu kaunokki:hasPublisher ?publisher .
  OPTIONAL { ?publisher skos:prefLabel ?publisher_name }


} 
"""

# %%
# query graph
print('\n\n*** constructing the graph')
sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")

sparql.setQuery(PREFIXES + Q_fi)

sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])

sparql.setReturnFormat(TURTLE)
results = sparql.query().convert()
# Out:
# *** constructing the graph

# %%
f_k = Graph()

f_k.parse(data=results, format="turtle")
# Out:
# <Graph identifier=N5aefa24a68e244e0bf61f4c56cec02ff (<class 'rdflib.graph.Graph'>)>

# %%
# existing graphs


f = Graph()
f.parse('../../data/finnish_graph_new.nt')
# Out:
# <Graph identifier=Ncaf91d23c98b4cf486c78ca286132f0b (<class 'rdflib.graph.Graph'>)>

# %%
# foreign
g = Graph() #/u/98/peurat1/unix/Desktop/kirjasampo/data/graph2.ttl
#f.parse(data="../../data/finnish_graph2.nt", format="nt")

g.parse('../../data/nat_lang_graph.nt')
# Out:
# <Graph identifier=N6e7c7b50129e40548c4440db888fffbb (<class 'rdflib.graph.Graph'>)>

# %%
# genre

genre=pd.read_csv("../../data/genre_df.csv", sep="\t", index_col=0)
genre_dict={}
for i,v in genre.groupby("genrename").apply(lambda x: list(x["genre"])).iteritems():
   # print(i,v)
    #genre_dict[i]=" ".join(["<"+uri+">" for uri in v])
    genre_dict[i] =v

    
# cluster per genre information
# load genre graphs
g_fi = Graph() 
g_fi.parse("../../data/finnish_genre_theme.nt",format="nt")

g_fo = Graph() 
g_fo.parse("../data/translated_theme_genre_new.nt",format="nt")
# Out:
# <Graph identifier=Na95170cdd8c24829bb21dd025d811cd9 (<class 'rdflib.graph.Graph'>)>

# %%
# add together

F = f + f_k

# %%
G = g+g_k

# %%
from rdflib.namespace import RDF, SKOS
rel = rdflib.Namespace('http://ldf.fi/relse/')

# add the broader genre to these
g2=g_fi
check_q= """

    PREFIX rel: <http://ldf.fi/relse/> 
    PREFIX dct: <http://purl.org/dc/terms/>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

    SELECT ?broader (COUNT(DISTINCT ?teos) AS ?novels) WHERE 
    { ?genre rel:broaderCategory <CAT> .  ?teos rel:hasGenre ?genre . BIND (<CAT> as ?broader ) }
    GROUP BY ?broader

    """

allres={key:[] for key in genre_dict.keys()}
for key,val in genre_dict.items():
    #if len(v)> 1:
    print(key)
    # insert broader
    
    
    g2.add((URIRef(key), RDF.type, rel.broaderCategory))
    
    
    for v in val:
        g2.add((URIRef(v),  rel.broaderCategory, URIRef(key)))
            
    
    c_q=check_q.replace("CAT", key)
    qres = g2.query(c_q)
    allres[key] += qres
    
    
category="lapset"
print("Found", allres[category], "novels of category", category)
# Out:
# elain
# era
# erotiikka
# fantasia
# historia
# huumori
# jannitys
# kauhu
# lapset
# nuoret
# rakkaus
# scifi
# sota
# urheilu
# uskonto
# Found [(rdflib.term.URIRef('lapset'), rdflib.term.Literal('986', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))] novels of category lapset

# %%
# add broader category to foreign

from rdflib.namespace import RDF, SKOS
rel = rdflib.Namespace('http://ldf.fi/relse/')

# add the broader genre to these
g_fo2=g_fo
check_q= """

    PREFIX rel: <http://ldf.fi/relse/> 
    PREFIX dct: <http://purl.org/dc/terms/>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

    SELECT ?broader (COUNT(DISTINCT ?teos) AS ?novels) WHERE 
    { ?genre rel:broaderCategory <CAT> .  ?teos rel:hasGenre ?genre . BIND (<CAT> as ?broader ) }
    GROUP BY ?broader

    """

allres={key:[] for key in genre_dict.keys()}
for key,val in genre_dict.items():
    #if len(v)> 1:
    print(key)
    # insert broader
    
    
    g_fo2.add((URIRef(key), RDF.type, rel.broaderCategory))
    
    
    for v in val:
        g_fo2.add((URIRef(v),  rel.broaderCategory, URIRef(key)))
            
    
    c_q=check_q.replace("CAT", key)
    qres = g_fo2.query(c_q)
    allres[key] += qres

category="lapset"
print("Found", allres[category], "novels of category", category)
# Out:
# elain
# era
# erotiikka
# fantasia
# historia
# huumori
# jannitys
# kauhu
# lapset
# nuoret
# rakkaus
# scifi
# sota
# urheilu
# uskonto
# Found [(rdflib.term.URIRef('lapset'), rdflib.term.Literal('960', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))] novels of category lapset

# %%
# step 1: query from the F and G networks [teos, publication, year, publisher]

# step 2: query from the author and lang networks df[teos,author,nat,lang]

# step 3: query from the genre network df[teos,genre]

# %%
# kaikki suomenkieliset

# suomenkielisen "marginaalikirjallisuuden kustantajat"

Q_y ="""

PREFIX foaf: <http://xmlns.com/foaf/0.1/> 
PREFIX kaunokki: <http://www.yso.fi/onto/kaunokki#> 
PREFIX rel: <http://ldf.fi/relse/> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT ?year ?teos  ?publisher ?pname ?author  #(COUNT(DISTINCT ?lang) as ?langCount)# (COUNT(DISTINCT ?nationality) as ?nationalityCount) #?gender #(COUNT(DISTINCT ?authorF) as ?f_authors) (COUNT(DISTINCT ?authorM) as ?m_authors)  
WHERE {
  # ?teos a rel:novel ; rel:hasPublication ?pub .
  # ?pub rel:pubYear ?year .
  # ?pub rel:hasPublisher ?publisher .
  OPTIONAL { ?publisher skos:prefLabel ?label .  }
  BIND(COALESCE(?label, "noname") AS ?pname)
  FILTER(?year < 2021)

  FILTER(?year > 1970)
  
 
  # ?teos rel:hasAuthor ?author. 

  
} GROUP BY ?year ?publisher ?author ?nationality ?teos

"""

qres = F.query(Q_y)
# convert to dict
div_fi=[{"year":str(row.asdict()['year'].toPython()),"publisher":str(row.asdict()['publisher'].toPython()),"pubName":str(row.asdict()['pname'].toPython()),"author":str(row.asdict()['author'].toPython()),"novel":str(row.asdict()['teos'].toPython())}  for row in qres]

# %%
df_fi=pd.DataFrame(div_fi).sort_values(by="year")
#f_y=f_y[f_y["country"]!="-"]
print(df_fi.publisher.nunique(), len(df_fi))
df_fi.drop_duplicates().tail(10)
# Out:
# 778 16496
#        year                                          publisher  \
# 6290   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 6300   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 6319   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 6320   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 15067  2020         http://data.kirjasampo.fi/actor_Sanoma+Pro
# 6327   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 6378   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 6379   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 6282   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 16495  2020                    http://www.btj.fi/actor_Aurinko
#
#                         pubName  \
# 6290   Kustannusosakeyhtiö Teos
# 6300                      Tammi
# 6319                      Tammi
# 6320                      Tammi
# 15067                Sanoma Pro
# 6327                 Karisto Oy
# 6378                       WSOY
# 6379      BoD - Books on Demand
# 6282                Omakustanne
# 16495         Aurinko Kustannus
#
#                                                   author  \
# 6290   http://www.yso.fi/onto/kaunokki#person_1231760...
# 6300   http://www.yso.fi/onto/kaunokki#person_1231759...
# 6319   http://seco.tkk.fi/saha3/u161e1513-7f91-4502-a...
# 6320   http://www.yso.fi/onto/kaunokki#person_1231759...
# 15067  http://www.yso.fi/onto/kaunokki#person_1231759...
# 6327   http://seco.tkk.fi/saha3/ue814a7ea-cc2f-4dfd-9...
# 6378     http://data.kirjasampo.fi/actor_Rantala%2C+Heli
# 6379   http://www.yso.fi/onto/kaunokki#person_1231759...
# 6282       http://data.kirjasampo.fi/actor_Kivi%2C+Jouko
# 16495  http://seco.tkk.fi/saha3/uf6c4db79-57f6-49a5-b...
#
#                                                    novel
# 6290      http://data.kirjasampo.fi/abstractWork_7086810
# 6300      http://data.kirjasampo.fi/abstractWork_7029269
# 6319   http://data.kirjasampo.fi/abstractWork_9789513...
# 6320   http://data.kirjasampo.fi/abstractWork_9789513...
# 15067     http://data.kirjasampo.fi/abstractWork_7094068
# 6327      http://data.kirjasampo.fi/abstractWork_7045181
# 6378      http://data.kirjasampo.fi/abstractWork_7081511
# 6379      http://data.kirjasampo.fi/abstractWork_7151242
# 6282      http://data.kirjasampo.fi/abstractWork_7148070
# 16495     http://data.kirjasampo.fi/abstractWork_7057637

# %%
# finnish authors, gender and nationality

# %%
Q_auth ="""

PREFIX foaf: <http://xmlns.com/foaf/0.1/> 
PREFIX kaunokki: <http://www.yso.fi/onto/kaunokki#> 
PREFIX rel: <http://ldf.fi/relse/> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT ?year ?teos  ?author ?nat ?gender #(COUNT(DISTINCT ?lang) as ?langCount)# (COUNT(DISTINCT ?nationality) as ?nationalityCount) #?gender #(COUNT(DISTINCT ?authorF) as ?f_authors) (COUNT(DISTINCT ?authorM) as ?m_authors)  
WHERE {
  # ?teos a rel:novel ; rel:pubYear ?year .
  
  FILTER(?year < 2021)

  FILTER(?year > 1970)
  
  # languages
  #?teos rel:langOrig ?lang . 
  
 
  # ?teos rel:hasAuthor ?author. 
    OPTIONAL { ?author rel:authorNationality ?nationality. }
    BIND(COALESCE(?nationality, "nonat") AS ?nat)
    
    OPTIONAL { ?author foaf:gender ?foafgender }
    BIND(COALESCE(?foafgender, "unk") AS ?gender)

  
} GROUP BY  ?author ?nationality ?teos ?year ?gender

"""

qres = f.query(Q_auth)
# convert to dict
au_fi=[{"year":str(row.asdict()['year'].toPython()),"author":str(row.asdict()['author'].toPython()),"nat":str(row.asdict()['nat'].toPython()),"gender":str(row.asdict()['gender'].toPython()),"novel":str(row.asdict()['teos'].toPython())}  for row in qres]

# %%
audf_fi=pd.DataFrame(au_fi).rename({"teos":"novel"}, axis=1)
#f_y=f_y[f_y["country"]!="-"]
print(audf_fi.author.nunique(), len(audf_fi), len(audf_fi.drop_duplicates(["novel","author"])),  len(audf_fi.drop_duplicates(["novel","author","year"])))
audf_fi.drop_duplicates().tail(10)
# Out:
# 5380 16816 16687 16738
#        year                                             author  \
# 16806  1973  http://www.yso.fi/onto/kaunokki#person_1231759...
# 16807  1993  http://seco.tkk.fi/saha3/ufd455299-db24-4d0d-8...
# 16808  1978  http://www.yso.fi/onto/kaunokki#person_1231759...
# 16809  2018     http://data.kirjasampo.fi/actor_Aalto%2C+Jorma
# 16810  2008  http://www.yso.fi/onto/kaunokki#person_1231759...
# 16811  2019     http://data.kirjasampo.fi/actor_Nikki%2C+Teemu
# 16812  2019  http://data.kirjasampo.fi/actor_P%C3%B6s%C3%B6...
# 16813  2020    http://data.kirjasampo.fi/actor_Silvan%2C+Heidi
# 16814  1990  http://www.yso.fi/onto/kaunokki#person_1231759...
# 16815  2000  http://www.yso.fi/onto/kaunokki#person_1231759...
#
#                                       nat  \
# 16806  http://www.yso.fi/onto/koko/p35259
# 16807  http://www.yso.fi/onto/koko/p35259
# 16808  http://www.yso.fi/onto/koko/p35259
# 16809  http://www.yso.fi/onto/koko/p35259
# 16810  http://www.yso.fi/onto/koko/p35259
# 16811  http://www.yso.fi/onto/koko/p35259
# 16812  http://www.yso.fi/onto/koko/p35259
# 16813  http://www.yso.fi/onto/koko/p35259
# 16814  http://www.yso.fi/onto/koko/p35259
# 16815  http://www.yso.fi/onto/koko/p35259
#
#                                        gender  \
# 16806                                     unk
# 16807  http://www.yso.fi/onto/kaunokki#female
# 16808    http://www.yso.fi/onto/kaunokki#male
# 16809    http://www.yso.fi/onto/kaunokki#male
# 16810    http://www.yso.fi/onto/kaunokki#male
# 16811    http://www.yso.fi/onto/kaunokki#male
# 16812    http://www.yso.fi/onto/kaunokki#male
# 16813  http://www.yso.fi/onto/kaunokki#female
# 16814    http://www.yso.fi/onto/kaunokki#male
# 16815    http://www.yso.fi/onto/kaunokki#male
#
#                                                    novel
# 16806        http://www.yso.fi/onto/kaunokki#ateos_45153
# 16807  http://seco.tkk.fi/saha3/u9b5b7c82-881f-4232-a...
# 16808  http://seco.tkk.fi/saha3/u52018df8-5fc4-4f4d-9...
# 16809     http://data.kirjasampo.fi/abstractWork_6846349
# 16810        http://www.yso.fi/onto/kaunokki#ateos_31972
# 16811     http://data.kirjasampo.fi/abstractWork_6969400
# 16812     http://data.kirjasampo.fi/abstractWork_6969400
# 16813     http://data.kirjasampo.fi/abstractWork_7037934
# 16814        http://www.yso.fi/onto/kaunokki#ateos_38615
# 16815        http://www.yso.fi/onto/kaunokki#ateos_15464

# %%
df_fi2=audf_fi.merge(df_fi, on=["novel","author","year"], how="left", suffixes=["_au",""])

# %%
df_fi2
# Out:
#        year                                             author  \
# 0      2017  http://data.kirjasampo.fi/actor_Sovij%C3%A4rvi...
# 1      2013         http://www.btj.fi/actor_Piiroinen%2C+Aulis
# 2      1972  http://seco.tkk.fi/saha3/uc84440c2-42e7-4ba7-b...
# 3      2010  http://data.kirjasampo.fi/actor_Vinnurva%2C+Pe...
# 4      2017        http://www.btj.fi/actor_Matilainen%2C+Pekka
# ...     ...                                                ...
# 16845  2019     http://data.kirjasampo.fi/actor_Nikki%2C+Teemu
# 16846  2019  http://data.kirjasampo.fi/actor_P%C3%B6s%C3%B6...
# 16847  2020    http://data.kirjasampo.fi/actor_Silvan%2C+Heidi
# 16848  1990  http://www.yso.fi/onto/kaunokki#person_1231759...
# 16849  2000  http://www.yso.fi/onto/kaunokki#person_1231759...
#
#                                       nat  \
# 0      http://www.yso.fi/onto/koko/p35259
# 1      http://www.yso.fi/onto/koko/p35259
# 2      http://www.yso.fi/onto/koko/p35259
# 3      http://www.yso.fi/onto/koko/p35259
# 4      http://www.yso.fi/onto/koko/p35259
# ...                                   ...
# 16845  http://www.yso.fi/onto/koko/p35259
# 16846  http://www.yso.fi/onto/koko/p35259
# 16847  http://www.yso.fi/onto/koko/p35259
# 16848  http://www.yso.fi/onto/koko/p35259
# 16849  http://www.yso.fi/onto/koko/p35259
#
#                                        gender  \
# 0        http://www.yso.fi/onto/kaunokki#male
# 1        http://www.yso.fi/onto/kaunokki#male
# 2      http://www.yso.fi/onto/kaunokki#female
# 3        http://www.yso.fi/onto/kaunokki#male
# 4        http://www.yso.fi/onto/kaunokki#male
# ...                                       ...
# 16845    http://www.yso.fi/onto/kaunokki#male
# 16846    http://www.yso.fi/onto/kaunokki#male
# 16847  http://www.yso.fi/onto/kaunokki#female
# 16848    http://www.yso.fi/onto/kaunokki#male
# 16849    http://www.yso.fi/onto/kaunokki#male
#
#                                                    novel  \
# 0         http://data.kirjasampo.fi/abstractWork_4492055
# 1         http://data.kirjasampo.fi/abstractWork_4014830
# 2            http://www.yso.fi/onto/kaunokki#ateos_20145
# 3      http://data.kirjasampo.fi/abstractWork_9789529...
# 4         http://data.kirjasampo.fi/abstractWork_4409323
# ...                                                  ...
# 16845     http://data.kirjasampo.fi/abstractWork_6969400
# 16846     http://data.kirjasampo.fi/abstractWork_6969400
# 16847     http://data.kirjasampo.fi/abstractWork_7037934
# 16848        http://www.yso.fi/onto/kaunokki#ateos_38615
# 16849        http://www.yso.fi/onto/kaunokki#ateos_15464
#
#                                                publisher  \
# 0                 http://data.kirjasampo.fi/actor_Arsmat
# 1      http://www.seco.tkk.fi/applications/saha#Insta...
# 2      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 3           http://data.kirjasampo.fi/actor_IPE+Tuoteapu
# 4      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# ...                                                  ...
# 16845  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 16846  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 16847  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 16848  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 16849  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
#
#                          pubName
# 0                         Arsmat
# 1                  Mediapinta Oy
# 2                  Weilin + Göös
# 3                   IPE Tuoteapu
# 4                          Atena
# ...                          ...
# 16845  Kustannusosakeyhtiö Otava
# 16846  Kustannusosakeyhtiö Otava
# 16847                 Myllylahti
# 16848  Kustannusosakeyhtiö Otava
# 16849                       WSOY
#
# [16850 rows x 7 columns]

# %%
# 
print(len(df_fi.drop_duplicates(["novel","year"])),  
     len(df_fi2.drop_duplicates(["novel","year"])),
      len(audf_fi.drop_duplicates(["novel","year"]))
     )

# df_fi2 has all!
# Out:
# 16087 16363 16363

# %%
# df_fi2 is the correct one to use

# %%
#df_fi2.to_csv("../../data/fi_au_pub.csv", sep="\t")

# %%
## viihde: select rakkaus, jannitys ja huumori

# hae kaikki teokset

Q= """

    PREFIX rel: <http://ldf.fi/relse/> 
    PREFIX dct: <http://purl.org/dc/terms/>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

    SELECT DISTINCT ?broader ?teos ?year WHERE 
    { ?genre rel:broaderCategory <CAT> .  
        # ?teos rel:hasGenre ?genre . 
        BIND (<CAT> as ?broader ) 
        # ?teos rel:pubYear ?year .
        #?teos rel:hasAuthor ?author.
       #?author foaf:gender ?gender .
       # OPTIONAL {?author rel:authorNationality ?nat1 . }
        
        #BIND(COALESCE(?gender1, "unk") AS ?gender)
        
        
        }
    GROUP BY ?teos ?year ?broader # ?author

    """

viihde_genres_fi=[]
for cat in ["rakkaus","jannitys","huumori"]:
    print(cat)
    q= Q.replace("CAT",cat)
    qres = g2.query(q)
    genre =[{"genre":str(row.asdict()['broader'].toPython()),"year":str(row.asdict()['year'].toPython()),"novel":str(row.asdict()['teos'].toPython())}  for row in qres]
    viihde_genres_fi.append(genre)
# Out:
# rakkaus
# jannitys
# huumori

# %%
df_fi_genre= pd.DataFrame()

for a in viihde_genres_fi:
    df_fi_genre= pd.concat([df_fi_genre, pd.DataFrame(a)])

print(len(df_fi_genre))
print(df_fi_genre.novel.nunique())
df_fi_genre["year"]=pd.to_numeric(df_fi_genre["year"])
df_fi_genre["decade"]=(df_fi_genre["year"]-1)- ((df_fi_genre["year"]-1)%10)
df_fi_genre.sort_values(by="year", inplace=True)
df_fi_genre.head()
# Out:
# 4687
# 4503
#          genre  year                                        novel  decade
# 1291  jannitys  1971  http://www.yso.fi/onto/kaunokki#ateos_45406    1970
# 830   jannitys  1971  http://www.yso.fi/onto/kaunokki#ateos_28462    1970
# 1679  jannitys  1971  http://www.yso.fi/onto/kaunokki#ateos_40845    1970
# 255    rakkaus  1971  http://www.yso.fi/onto/kaunokki#ateos_49172    1970
# 2341  jannitys  1971  http://www.yso.fi/onto/kaunokki#ateos_44793    1970

# %%
df_fi_final=df_fi2.merge(df_fi_genre, on=["novel"], how="left", suffixes=["","_genre"])

# %%
print(len(df_fi.drop_duplicates(["novel","year"])),  
     len(df_fi2.drop_duplicates(["novel","year"])),
      len(audf_fi.drop_duplicates(["novel","year"])),
      len(df_fi_final.drop_duplicates(["novel","year"]))
     )
# Out:
# 16087 16363 16363 16363

# %%
#df_fi_final.to_csv("../../data/df_fi_all.csv", sep="\t")

# %%
# same for foreign works

# kaikki ei-suomenkieliset



Q_y ="""

PREFIX foaf: <http://xmlns.com/foaf/0.1/> 
PREFIX kaunokki: <http://www.yso.fi/onto/kaunokki#> 
PREFIX rel: <http://ldf.fi/relse/> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT ?year ?teos  ?publisher ?pname ?author  #(COUNT(DISTINCT ?lang) as ?langCount)# (COUNT(DISTINCT ?nationality) as ?nationalityCount) #?gender #(COUNT(DISTINCT ?authorF) as ?f_authors) (COUNT(DISTINCT ?authorM) as ?m_authors)  
WHERE {
  # ?teos a rel:novel ; rel:hasPublication ?pub .
  # ?pub rel:pubYear ?year .
  # ?pub rel:hasPublisher ?publisher .
  OPTIONAL { ?publisher skos:prefLabel ?label .  }
  BIND(COALESCE(?label, "noname") AS ?pname)
  FILTER(?year < 2021)

  FILTER(?year > 1970)
  
 
  # ?teos rel:hasAuthor ?author. 

  
} GROUP BY ?year ?publisher ?author ?teos

"""

qres = G.query(Q_y)
# convert to dict
div_fo=[{"year":str(row.asdict()['year'].toPython()),"publisher":str(row.asdict()['publisher'].toPython()),"pubName":str(row.asdict()['pname'].toPython()),"author":str(row.asdict()['author'].toPython()),"novel":str(row.asdict()['teos'].toPython())}  for row in qres]

# %%
df_fo=pd.DataFrame(div_fo).sort_values(by="year")

print(df_fo.publisher.nunique(), len(df_fo))
df_fo.drop_duplicates().tail(10)
# Out:
# 323 18100
#        year                                          publisher  \
# 107    2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 7081   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 13997  2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 1342   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 10681  2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 10396  2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 7077   2020  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 9915   2020    http://data.kirjasampo.fi/actor_Tiberius+kirjat
# 8386   2020  http://data.kirjasampo.fi/actor_HarperCollins+...
# 12834  2020        http://data.kirjasampo.fi/actor_Aula+%26+Co
#
#                          pubName  \
# 107    Kustannusosakeyhtiö Otava
# 7081   Kustannusosakeyhtiö Otava
# 13997                      Tammi
# 1342       Gummerus Kustannus Oy
# 10681      Gummerus Kustannus Oy
# 10396                       WSOY
# 7077                   Readme.fi
# 9915             Tiberius kirjat
# 8386     HarperCollins Nordic AB
# 12834                  Aula & Co
#
#                                                   author  \
# 107    http://data.kirjasampo.fi/actor_Bengtsdotter%2...
# 7081   http://data.kirjasampo.fi/actor_Lundberg%2C+Sofia
# 13997     http://data.kirjasampo.fi/actor_Aciman%2C+Andr
# 1342   http://data.kirjasampo.fi/actor_Luiselli%2C+Va...
# 10681    http://data.kirjasampo.fi/actor_Offill%2C+Jenny
# 10396  http://data.kirjasampo.fi/actor_Hurley%2C+Andr...
# 7077   http://seco.tkk.fi/saha3/uc3d9a509-6b8e-4e36-b...
# 9915   http://www.yso.fi/onto/kaunokki#person_1231759...
# 8386   http://www.yso.fi/onto/kaunokki#person_1231759...
# 12834  http://data.kirjasampo.fi/actor_Colling+Nielse...
#
#                                                    novel
# 107       http://data.kirjasampo.fi/abstractWork_7084706
# 7081      http://data.kirjasampo.fi/abstractWork_6984203
# 13997     http://data.kirjasampo.fi/abstractWork_6980724
# 1342      http://data.kirjasampo.fi/abstractWork_7056178
# 10681     http://data.kirjasampo.fi/abstractWork_7089780
# 10396     http://data.kirjasampo.fi/abstractWork_7081432
# 7077      http://data.kirjasampo.fi/abstractWork_7039492
# 9915   http://seco.tkk.fi/saha3/u4f745a51-f364-44aa-b...
# 8386      http://data.kirjasampo.fi/abstractWork_4293866
# 12834     http://data.kirjasampo.fi/abstractWork_6847141

# %%
#df_fo[df_fo["publisher"].isna()]

# %%
Q_auth ="""

PREFIX foaf: <http://xmlns.com/foaf/0.1/> 
PREFIX kaunokki: <http://www.yso.fi/onto/kaunokki#> 
PREFIX rel: <http://ldf.fi/relse/> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT ?year ?teos  ?author ?nat ?gender ?lang #(COUNT(DISTINCT ?lang) as ?langCount)# (COUNT(DISTINCT ?nationality) as ?nationalityCount) #?gender #(COUNT(DISTINCT ?authorF) as ?f_authors) (COUNT(DISTINCT ?authorM) as ?m_authors)  
WHERE {
  # ?teos a rel:novel ; rel:pubYear ?year .
  
  FILTER(?year < 2021)

  FILTER(?year > 1970)
  
   #languages
  # ?teos rel:langOrig ?lang . 
  
 
  # ?teos rel:hasAuthor ?author. 
    OPTIONAL { ?author rel:authorNationality ?nationality. }
    BIND(COALESCE(?nationality, "nonat") AS ?nat)
    
    OPTIONAL { ?author foaf:gender ?foafgender }
    BIND(COALESCE(?foafgender, "unk") AS ?gender)

  
} GROUP BY  ?author ?nationality ?teos ?year ?gender

"""

qres = g.query(Q_auth)
# convert to dict
au_fo=[{"year":str(row.asdict()['year'].toPython()),"author":str(row.asdict()['author'].toPython()),"nat":str(row.asdict()['nat'].toPython()),"gender":str(row.asdict()['gender'].toPython()),"novel":str(row.asdict()['teos'].toPython()),"lang":str(row.asdict()['lang'].toPython())}  for row in qres]

# %%
audf_fo=pd.DataFrame(au_fo).rename({"teos":"novel"}, axis=1)
#f_y=f_y[f_y["country"]!="-"]
print(df_fo.novel.nunique(), len(df_fo),audf_fo.author.nunique(), len(audf_fo), len(audf_fo.drop_duplicates(["novel"])),  len(audf_fo.drop_duplicates(["novel","author","year"])))
audf_fo.drop_duplicates().tail(10)
# Out:
# 17189 18100 6025 18820 17317 18156
#        year                                             author  \
# 18810  2017         http://www.btj.fi/actor_Strandberg%2C+Mats
# 18811  2009        http://www.btj.fi/actor_Verhulst%2C+Dimitri
# 18812  1994  http://www.yso.fi/onto/kaunokki#person_1231759...
# 18813  1978  http://www.yso.fi/onto/kaunokki#person_1231760...
# 18814  1981  http://seco.tkk.fi/saha3/ud929b2e8-1ab3-4f9f-9...
# 18815  2011  http://www.yso.fi/onto/kaunokki#person_1231759...
# 18816  1996  http://www.yso.fi/onto/kaunokki#character_1231...
# 18817  1996  http://www.yso.fi/onto/kaunokki#person_1231759...
# 18818  1978  http://seco.tkk.fi/saha3/u0548430a-0211-458d-8...
# 18819  2006  http://seco.tkk.fi/saha3/udb595e9a-651d-4e99-b...
#
#                                                      nat  \
# 18810                 http://www.yso.fi/onto/koko/p16897
# 18811                  http://www.yso.fi/onto/koko/p7333
# 18812                 http://www.yso.fi/onto/koko/p73101
# 18813  http://seco.tkk.fi/saha3/ube6cbdbc-1b7d-4e42-9...
# 18814                  http://www.yso.fi/onto/koko/p2224
# 18815                 http://www.yso.fi/onto/koko/p35259
# 18816                  http://www.yso.fi/onto/koko/p2224
# 18817                  http://www.yso.fi/onto/koko/p2224
# 18818                  http://www.yso.fi/onto/koko/p2224
# 18819                  http://www.yso.fi/onto/koko/p2224
#
#                                        gender  \
# 18810    http://www.yso.fi/onto/kaunokki#male
# 18811    http://www.yso.fi/onto/kaunokki#male
# 18812  http://www.yso.fi/onto/kaunokki#female
# 18813    http://www.yso.fi/onto/kaunokki#male
# 18814    http://www.yso.fi/onto/kaunokki#male
# 18815    http://www.yso.fi/onto/kaunokki#male
# 18816  http://www.yso.fi/onto/kaunokki#female
# 18817                                     unk
# 18818    http://www.yso.fi/onto/kaunokki#male
# 18819    http://www.yso.fi/onto/kaunokki#male
#
#                                                    novel  \
# 18810     http://data.kirjasampo.fi/abstractWork_4437454
# 18811                       http://www.btj.fi/at_1399348
# 18812         http://www.yso.fi/onto/kaunokki#ateos_5064
# 18813         http://www.yso.fi/onto/kaunokki#ateos_7658
# 18814  http://seco.tkk.fi/saha3/ufc9799ee-59d2-437b-8...
# 18815                       http://www.btj.fi/at_1591998
# 18816         http://www.yso.fi/onto/kaunokki#ateos_5288
# 18817         http://www.yso.fi/onto/kaunokki#ateos_5288
# 18818  http://seco.tkk.fi/saha3/u66fb0c24-e465-4722-b...
# 18819  http://seco.tkk.fi/saha3/u011edfe4-1abc-4397-8...
#
#                                    lang
# 18810  http://lexvo.org/id/iso639-3/swe
# 18811  http://lexvo.org/id/iso639-3/nld
# 18812  http://lexvo.org/id/iso639-3/eng
# 18813  http://lexvo.org/id/iso639-3/spa
# 18814  http://lexvo.org/id/iso639-3/eng
# 18815  http://lexvo.org/id/iso639-3/swe
# 18816  http://lexvo.org/id/iso639-3/eng
# 18817  http://lexvo.org/id/iso639-3/eng
# 18818  http://lexvo.org/id/iso639-3/eng
# 18819  http://lexvo.org/id/iso639-3/eng

# %%
df_fo2=audf_fo.merge(df_fo, on=["novel","author","year"], how="left", suffixes=["_au",""])

# %%
df_fo2[df_fo2["publisher"].isna()]
# Out:
#        year                                             author  \
# 27     1982  http://www.yso.fi/onto/kaunokki#person_1231759...
# 101    1997  http://www.yso.fi/onto/kaunokki#person_1232726...
# 546    1988  http://www.yso.fi/onto/kaunokki#person_1232726...
# 604    1973  http://www.yso.fi/onto/kaunokki#character_1231...
# 677    1977  http://www.yso.fi/onto/kaunokki#person_1231759...
# ...     ...                                                ...
# 18676  2001  http://www.yso.fi/onto/kaunokki#person_1231759...
# 18740  2001  http://www.yso.fi/onto/kaunokki#person_1231760...
# 18756  1984  http://www.yso.fi/onto/kaunokki#person_1231759...
# 18862  1994  http://www.yso.fi/onto/kaunokki#person_1231759...
# 18863  1994  http://www.yso.fi/onto/kaunokki#person_1231759...
#
#                                                      nat  \
# 27                     http://www.yso.fi/onto/koko/p2224
# 101    http://seco.tkk.fi/saha3/u5aa143b0-c88f-47a0-8...
# 546                   http://www.yso.fi/onto/koko/p73101
# 604                   http://www.yso.fi/onto/koko/p73101
# 677                    http://www.yso.fi/onto/koko/p2224
# ...                                                  ...
# 18676                                              nonat
# 18740                  http://www.yso.fi/onto/koko/p2224
# 18756                  http://www.yso.fi/onto/koko/p8327
# 18862                 http://www.yso.fi/onto/koko/p53709
# 18863                 http://www.yso.fi/onto/koko/p73101
#
#                                        gender  \
# 27       http://www.yso.fi/onto/kaunokki#male
# 101      http://www.yso.fi/onto/kaunokki#male
# 546    http://www.yso.fi/onto/kaunokki#female
# 604      http://www.yso.fi/onto/kaunokki#male
# 677    http://www.yso.fi/onto/kaunokki#female
# ...                                       ...
# 18676  http://www.yso.fi/onto/kaunokki#female
# 18740    http://www.yso.fi/onto/kaunokki#male
# 18756    http://www.yso.fi/onto/kaunokki#male
# 18862    http://www.yso.fi/onto/kaunokki#male
# 18863    http://www.yso.fi/onto/kaunokki#male
#
#                                              novel  \
# 27      http://www.yso.fi/onto/kaunokki#ateos_6298
# 101    http://www.yso.fi/onto/kaunokki#ateos_40961
# 546     http://www.yso.fi/onto/kaunokki#ateos_6765
# 604     http://www.yso.fi/onto/kaunokki#ateos_3666
# 677    http://www.yso.fi/onto/kaunokki#ateos_12744
# ...                                            ...
# 18676   http://www.yso.fi/onto/kaunokki#ateos_3255
# 18740  http://www.yso.fi/onto/kaunokki#ateos_11079
# 18756  http://www.yso.fi/onto/kaunokki#ateos_10368
# 18862   http://www.yso.fi/onto/kaunokki#ateos_2047
# 18863   http://www.yso.fi/onto/kaunokki#ateos_2047
#
#                                    lang publisher pubName
# 27     http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 101    http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 546    http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 604    http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 677    http://lexvo.org/id/iso639-3/eng       NaN     NaN
# ...                                 ...       ...     ...
# 18676  http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 18740  http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 18756  http://lexvo.org/id/iso639-3/rus       NaN     NaN
# 18862  http://lexvo.org/id/iso639-3/eng       NaN     NaN
# 18863  http://lexvo.org/id/iso639-3/eng       NaN     NaN
#
# [147 rows x 8 columns]

# %%
# 
print(len(df_fo.drop_duplicates(["novel","year"])),  
     len(df_fo2.drop_duplicates(["novel","year"])),
      len(audf_fo.drop_duplicates(["novel","year"]))
     )

# df_fo2 has all!
# Out:
# 17407 17539 17539

# %%
## viihde: select rakkaus, jannitys ja huumori

# hae kaikki teokset

Q= """

    PREFIX rel: <http://ldf.fi/relse/> 
    PREFIX dct: <http://purl.org/dc/terms/>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

    SELECT DISTINCT ?broader ?teos ?year ?lang  ?author WHERE 
    { ?genre rel:broaderCategory <CAT> .  
        # ?teos rel:hasGenre ?genre . 
        BIND (<CAT> as ?broader ) 
        # ?teos rel:pubYear ?year .
        # ?teos rel:hasAuthor ?author.
       #?author foaf:gender ?gender .
       # OPTIONAL {?author rel:authorNationality ?nat1 . }
        
        #BIND(COALESCE(?gender1, "unk") AS ?gender)
        # ?teos rel:langOrig ?lang .
        
        }
    GROUP BY ?teos ?lang ?year ?broader  ?author

    """

viihde_genres=[]
for cat in ["rakkaus","jannitys","huumori"]:
    print(cat)
    q= Q.replace("CAT",cat)
    qres = g_fo2.query(q)
    genre =[{"genre":str(row.asdict()['broader'].toPython()),"year":str(row.asdict()['year'].toPython()),"novel":str(row.asdict()['teos'].toPython()),"lang":str(row.asdict()['lang'].toPython()),"author":str(row.asdict()['author'].toPython())}  for row in qres]
    viihde_genres.append(genre)
# Out:
# rakkaus
# jannitys
# huumori

# %%
# now add genre

df_fo_genre= pd.DataFrame()

for a in viihde_genres:
    df_fo_genre= pd.concat([df_fo_genre, pd.DataFrame(a)])

print(len(df_fo_genre))
print(df_fo_genre.novel.nunique())
df_fo_genre["year"]=pd.to_numeric(df_fo_genre["year"])
df_fo_genre["decade"]=(df_fo_genre["year"]-1)- ((df_fo_genre["year"]-1)%10)
df_fo_genre.sort_values(by="year", inplace=True)
df_fo_genre.head()
# Out:
# 9379
# 8502
#          genre  year                                              novel  \
# 2300  jannitys  1971         http://www.yso.fi/onto/kaunokki#ateos_7501
# 1237   rakkaus  1971         http://www.yso.fi/onto/kaunokki#ateos_3931
# 2418  jannitys  1971         http://www.yso.fi/onto/kaunokki#ateos_4288
# 2424  jannitys  1971  http://seco.tkk.fi/saha3/u6774e1fb-9c17-40b8-b...
# 4723  jannitys  1971                       http://www.btj.fi/at_1479755
#
#                                   lang  \
# 2300  http://lexvo.org/id/iso639-3/fra
# 1237  http://lexvo.org/id/iso639-3/fra
# 2418  http://lexvo.org/id/iso639-3/eng
# 2424  http://lexvo.org/id/iso639-3/eng
# 4723  http://lexvo.org/id/iso639-3/swe
#
#                                                  author  decade
# 2300  http://www.yso.fi/onto/kaunokki#person_1231760...    1970
# 1237  http://www.yso.fi/onto/kaunokki#person_1231760...    1970
# 2418  http://www.yso.fi/onto/kaunokki#person_1231759...    1970
# 2424  http://www.yso.fi/onto/kaunokki#person_1231759...    1970
# 4723  http://seco.tkk.fi/saha3/u0e364bf4-73f6-446a-9...    1970

# %%
df_fo_final=df_fo2.merge(df_fo_genre, on=["novel"], how="left", suffixes=["","_genre"])

# %%
print(len(df_fo.drop_duplicates(["novel","year"])),  
     len(df_fo2.drop_duplicates(["novel","year"])),
      len(audf_fo.drop_duplicates(["novel","year"])),
      len(df_fo_final.drop_duplicates(["novel","year"]))
     )
# Out:
# 17407 17539 17539 17539

# %%
df_fo_final
# Out:
#        year                                             author  \
# 0      1984  http://www.yso.fi/onto/kaunokki#person_1231759...
# 1      2005  http://www.yso.fi/onto/kaunokki#person_1231759...
# 2      2005  http://www.yso.fi/onto/kaunokki#person_1231759...
# 3      2015  http://www.yso.fi/onto/kaunokki#person_1231758...
# 4      2011             http://www.btj.fi/actor_Hogan%2C+Chuck
# ...     ...                                                ...
# 20242  1996  http://www.yso.fi/onto/kaunokki#character_1231...
# 20243  1996  http://www.yso.fi/onto/kaunokki#person_1231759...
# 20244  1996  http://www.yso.fi/onto/kaunokki#person_1231759...
# 20245  1978  http://seco.tkk.fi/saha3/u0548430a-0211-458d-8...
# 20246  2006  http://seco.tkk.fi/saha3/udb595e9a-651d-4e99-b...
#
#                                                      nat  \
# 0                     http://www.yso.fi/onto/koko/p35259
# 1                      http://www.yso.fi/onto/koko/p2224
# 2      http://seco.tkk.fi/saha3/u4efb5155-076b-4800-9...
# 3                      http://www.yso.fi/onto/koko/p6292
# 4                     http://www.yso.fi/onto/koko/p73101
# ...                                                  ...
# 20242                  http://www.yso.fi/onto/koko/p2224
# 20243                  http://www.yso.fi/onto/koko/p2224
# 20244                  http://www.yso.fi/onto/koko/p2224
# 20245                  http://www.yso.fi/onto/koko/p2224
# 20246                  http://www.yso.fi/onto/koko/p2224
#
#                                        gender  \
# 0        http://www.yso.fi/onto/kaunokki#male
# 1      http://www.yso.fi/onto/kaunokki#female
# 2      http://www.yso.fi/onto/kaunokki#female
# 3        http://www.yso.fi/onto/kaunokki#male
# 4        http://www.yso.fi/onto/kaunokki#male
# ...                                       ...
# 20242  http://www.yso.fi/onto/kaunokki#female
# 20243                                     unk
# 20244                                     unk
# 20245    http://www.yso.fi/onto/kaunokki#male
# 20246    http://www.yso.fi/onto/kaunokki#male
#
#                                                    novel  \
# 0             http://www.yso.fi/onto/kaunokki#ateos_8105
# 1             http://www.yso.fi/onto/kaunokki#ateos_1981
# 2             http://www.yso.fi/onto/kaunokki#ateos_1981
# 3                           http://www.btj.fi/at_1674759
# 4                           http://www.btj.fi/at_1553291
# ...                                                  ...
# 20242         http://www.yso.fi/onto/kaunokki#ateos_5288
# 20243         http://www.yso.fi/onto/kaunokki#ateos_5288
# 20244         http://www.yso.fi/onto/kaunokki#ateos_5288
# 20245  http://seco.tkk.fi/saha3/u66fb0c24-e465-4722-b...
# 20246  http://seco.tkk.fi/saha3/u011edfe4-1abc-4397-8...
#
#                                    lang  \
# 0      http://lexvo.org/id/iso639-3/swe
# 1      http://lexvo.org/id/iso639-3/eng
# 2      http://lexvo.org/id/iso639-3/eng
# 3      http://lexvo.org/id/iso639-3/dan
# 4      http://lexvo.org/id/iso639-3/eng
# ...                                 ...
# 20242  http://lexvo.org/id/iso639-3/eng
# 20243  http://lexvo.org/id/iso639-3/eng
# 20244  http://lexvo.org/id/iso639-3/eng
# 20245  http://lexvo.org/id/iso639-3/eng
# 20246  http://lexvo.org/id/iso639-3/eng
#
#                                                publisher  \
# 0      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 1      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 2      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 3      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 4      http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# ...                                                  ...
# 20242  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 20243  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 20244  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 20245  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
# 20246  http://www.yso.fi/onto/kaunokki#Kustantaja_123...
#
#                          pubName     genre  year_genre  \
# 0                           WSOY       NaN         NaN
# 1      Kustannusosakeyhtiö Otava       NaN         NaN
# 2      Kustannusosakeyhtiö Otava       NaN         NaN
# 3          Gummerus Kustannus Oy  jannitys      2015.0
# 4                          Tammi  jannitys      2011.0
# ...                          ...       ...         ...
# 20242                 Karisto Oy   rakkaus      1996.0
# 20243                 Karisto Oy   rakkaus      1996.0
# 20244                 Karisto Oy   rakkaus      1996.0
# 20245      Gummerus Kustannus Oy  jannitys      1978.0
# 20246                       WSOY       NaN         NaN
#
#                              lang_genre  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3      http://lexvo.org/id/iso639-3/dan
# 4      http://lexvo.org/id/iso639-3/eng
# ...                                 ...
# 20242  http://lexvo.org/id/iso639-3/eng
# 20243  http://lexvo.org/id/iso639-3/eng
# 20244  http://lexvo.org/id/iso639-3/eng
# 20245  http://lexvo.org/id/iso639-3/eng
# 20246                               NaN
#
#                                             author_genre  decade
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3      http://www.yso.fi/onto/kaunokki#person_1231758...  2010.0
# 4                 http://www.btj.fi/actor_Hogan%2C+Chuck  2010.0
# ...                                                  ...     ...
# 20242  http://www.yso.fi/onto/kaunokki#character_1231...  1990.0
# 20243  http://www.yso.fi/onto/kaunokki#person_1231759...  1990.0
# 20244  http://www.yso.fi/onto/kaunokki#character_1231...  1990.0
# 20245  http://seco.tkk.fi/saha3/u0548430a-0211-458d-8...  1970.0
# 20246                                                NaN     NaN
#
# [20247 rows x 13 columns]

# %%
#df_fo_final.to_csv("../../data/df_fo_all.csv", sep="\t")

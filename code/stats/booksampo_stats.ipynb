# %%
# This notebook provides an overview of the BookSampo data as it is in the summer 2022.

# %%
# packages

import matplotlib.pyplot as plt
import numpy    as np
#import networkx as nx
from operator import itemgetter
import pandas   as pd
import rdflib as rdflib
import re
from scipy.signal import convolve2d
import seaborn as sns
from SPARQLWrapper import SPARQLWrapper, JSON, POST
import sys
from rdflib.namespace import XSD, Namespace
from rdflib.term import URIRef

import IPython
import pprint
pp = pprint.PrettyPrinter(indent=4)

import glob

# %%
from helpers import *
from constants import *

# %% [markdown]
# ## A comparison to 2013

# %%
# As of 2022

litworks ="""
SELECT   (COUNT(DISTINCT ?teos) as ?literaryWorks) (COUNT(DISTINCT ?edition) as ?editions) (COUNT(DISTINCT ?editionpart) as ?editionParts) (COUNT(DISTINCT ?alleditions) as ?allEditions) 
WHERE {
  # ?teos a/rdfs:subClassOf* <http://www.yso.fi/onto/kaunokki#teos> . # class teos or subclass of teos

  
  OPTIONAL { ?teos <http://www.yso.fi/onto/kaunokki#manifests_in> ?edition }
  OPTIONAL {?teos <http://www.yso.fi/onto/kaunokki#manifests_in_part> ?editionpart }
  BIND( COALESCE(?edition, ?editionpart) as ?alleditions)
  
  
}

"""

# Query works
sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
sparql.setQuery(PREFIXES + litworks)
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
results = sparql.query().convert()

vars = results['head']['vars']

#print("Query returned {} results".format(len(results["results"]["bindings"])))
lit = JSON2Pandas(results)


PICS =""" 
SELECT  (COUNT(DISTINCT ?kuva) as ?bookCovers) 
WHERE {
  # ?kuva a/rdfs:subClassOf* <http://www.yso.fi/onto/kaunokki#kansi> .
  
}
"""

# Query cover pictures
sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
sparql.setQuery(PREFIXES + PICS)
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
results = sparql.query().convert()

vars = results['head']['vars']

#print("Query returned {} results".format(len(results["results"]["bindings"])))
covers = JSON2Pandas(results)

# %%
# other features

Q =""" 
SELECT (COUNT(DISTINCT ?actor) as ?mainChars)  (COUNT(DISTINCT ?review) as ?contemporaryReviews)   (COUNT(DISTINCT ?link) AS ?weblinks) (COUNT(DISTINCT ?sarja) AS ?LitSeries) (COUNT(DISTINCT ?palkinto) AS ?litAwards) (COUNT(DISTINCT ?palkintosarja) AS ?litAwardSeries) 
(COUNT(DISTINCT ?film) AS ?movies)  (COUNT(DISTINCT ?person) AS ?people) (COUNT(DISTINCT ?authorpic) AS ?authorPics) (COUNT(DISTINCT ?publisher) AS ?publishers)

WHERE {

  { ?review a kaunokki:review . }
  
  UNION
  
  {
    # ?sarja a <http://www.yso.fi/onto/kaunokki#sarja> . }
  
   UNION
  
  {
    # ?teos a/rdfs:subClassOf* <http://www.yso.fi/onto/kaunokki#teos> . # class teos or subclass of teos
  	# ?teos kaunokki:paahenkilo ?actor . 
  }
  
  UNION {
   # ?palkinto a 	kaunokki:palkintoInstanssi . 
  }
  
   UNION {
   # ?s	kaunokki:palkintosarja ?palkintosarja . 
  }
  UNION {
  # ?film a <http://www.yso.fi/onto/kaunokki#film> . #==> elokuvat
  }
   UNION {
  # ?person a foaf:Person .
  }
   UNION {
  # ?authorpic a <http://seco.tkk.fi/saha3/kirjasampo/KirjailijanKuva> .
  }
  UNION
  
  {
    # ?publisher a kaunokki:kustantaja .
    
  }
  
  UNION {
    # ?link a kaunokki:Link .
}
  
}
"""

# Query cover pictures
sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
sparql.setQuery(PREFIXES + Q)
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
results = sparql.query().convert()

vars = results['head']['vars']

#print("Query returned {} results".format(len(results["results"]["bindings"])))
numbers = JSON2Pandas(results)

# %%
# join these queries
allnumbers = lit.join(covers).join(numbers)

print(allnumbers.T.style.to_latex())
# Out:
# \begin{tabular}{lr}
#  & 0 \\
# literaryWorks & 207771 \\
# editions & 213161 \\
# editionParts & 79447 \\
# allEditions & 285518 \\
# bookCovers & 112971 \\
# mainChars & 45397 \\
# contemporaryReviews & 14644 \\
# weblinks & 25017 \\
# LitSeries & 8374 \\
# litAwards & 6310 \\
# litAwardSeries & 290 \\
# movies & 2010 \\
# people & 62207 \\
# authorPics & 4140 \\
# publishers & 5455 \\
# \end{tabular}

# %% [markdown]
# *As of 2013*
# (done by Eetu Mäkelä)
#
# - Literary Works 93,000
# - Editions 127,000
# - Book Covers 27,000
# - Fictional Characters 19,000
# - Contemporary Reviews 15,000
# - Weblinks 10,000
# - Literary Series 2,900
# - Literary Awards 2,700
# - Literary Award Series 200
# - Movies 1,100
# - People (e.g. Authors) 29,000
# - Author’s Pictures 2,600
# - Publishers 2,600

# %% [markdown]
# ## Literary works per class

# %%
QUERY = """
SELECT  ?class_label ?bookclass (COUNT(DISTINCT ?id) as ?instanceCount) WHERE {
 # ?bookclass rdfs:subClassOf <http://www.yso.fi/onto/kaunokki#teos> ; skos:prefLabel ?class_label .
  FILTER(LANG(?class_label)='fi')
  
  # ?id a ?bookclass .
  # ?id kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin> .
} 

GROUP BY ?class_label ?bookclass
ORDER BY ?class_label

"""

# Query works
sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
sparql.setQuery(PREFIXES + QUERY)
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
results = sparql.query().convert()

vars = results['head']['vars']

print("Query returned {} results".format(len(results["results"]["bindings"])))
# Out:
# Query returned 24 results

# %%
data = JSON2Pandas(results)
data.reset_index()#set_index('id', inplace=True)
print(len(data))
display(data)
# Out:
# 24
#               class_label                                          bookclass  \
# 0       aforismikokoelmat  http://seco.tkk.fi/saha3/kirjasampo/Aforismiko...
# 1          esseekokoelmat              http://www.yso.fi/onto/kaunokki#essee
# 2     kansanrunokokoelmat         http://www.yso.fi/onto/kaunokki#kansanruno
# 3             kansanrunot    http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot
# 4          kokoomateokset        http://www.yso.fi/onto/kaunokki#kokoomateos
# 5              kuunnelmat     http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat
# 6   kuunnelmat, kokoelmat          http://www.yso.fi/onto/kaunokki#kuunnelma
# 7              kuvakirjat         http://www.yso.fi/onto/kaunokki#kuvakirjat
# 8        käsikirjoitukset      http://www.yso.fi/onto/kaunokki#kasikirjoitus
# 9        novellikokoelmat    http://www.yso.fi/onto/kaunokki#novellikokoelma
# 10               novellit  http://www.seco.tkk.fi/applications/saha#Insta...
# 11              näytelmät           http://www.yso.fi/onto/kaunokki#naytelma
# 12   näytelmät, kokoelmat  http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b...
# 13        pakinakokoelmat             http://www.yso.fi/onto/kaunokki#pakina
# 14                pakinat        http://seco.tkk.fi/saha3/kirjasampo/Pakinat
# 15               romaanit            http://www.yso.fi/onto/kaunokki#romaani
# 16          runokokoelmat  http://www.seco.tkk.fi/applications/saha#Insta...
# 17                  runot               http://www.yso.fi/onto/kaunokki#runo
# 18                  sadut          http://seco.tkk.fi/saha3/kirjasampo/Sadut
# 19      sarjakuva-albumit          http://www.yso.fi/onto/kaunokki#sarjakuva
# 20             sarjakuvat     http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat
# 21          satukokoelmat               http://www.yso.fi/onto/kaunokki#satu
# 22            tietokirjat  http://www.seco.tkk.fi/applications/saha#Insta...
# 23      vitsit ja kaskut   http://seco.tkk.fi/saha3/u578baac2-f84b-4906-a...
#
#     instanceCount
# 0             385
# 1             376
# 2             166
# 3              43
# 4            1759
# 5              59
# 6             144
# 7            3370
# 8              47
# 9            2794
# 10          18693
# 11           2164
# 12            144
# 13            820
# 14             52
# 15          23294
# 16          10698
# 17            353
# 18           8287
# 19           1758
# 20             35
# 21           1463
# 22           1159
# 23            485

# %%
class_count=data["class_label"]+" ("+data["instanceCount"].astype(str) +")"
class_count
# Out:
# 0         aforismikokoelmat (385)
# 1            esseekokoelmat (376)
# 2       kansanrunokokoelmat (166)
# 3                kansanrunot (43)
# 4           kokoomateokset (1759)
# 5                 kuunnelmat (59)
# 6     kuunnelmat, kokoelmat (144)
# 7               kuvakirjat (3370)
# 8           käsikirjoitukset (47)
# 9         novellikokoelmat (2794)
# 10               novellit (18693)
# 11               näytelmät (2164)
# 12     näytelmät, kokoelmat (144)
# 13          pakinakokoelmat (820)
# 14                   pakinat (52)
# 15               romaanit (23294)
# 16          runokokoelmat (10698)
# 17                    runot (353)
# 18                   sadut (8287)
# 19       sarjakuva-albumit (1758)
# 20                sarjakuvat (35)
# 21           satukokoelmat (1463)
# 22             tietokirjat (1159)
# 23        vitsit ja kaskut  (485)
# dtype: object

# %% [markdown]
# ## see annotations per class

# %%
# loop through all classes
Q = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a ?class . # teos is an abstract work
    #?teos kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin> . # if you want only literature originally written in Finnish
  
   OPTIONAL { 
    
    # ?teos a ?class .
    FILTER NOT EXISTS  { ?teos kaunokki:teema ?teema }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
variables = ["kaunokki:teema", "kaunokki:asiasana", "kaunokki:toimija" , "kaunokki:paahenkilo", "kaunokki:alkukieli", "kaunokki:genre", 
             "kaunokki:tekija", "kaunokki:paikka", "kaunokki:worldPlace", "kaunokki:manifests_in", "kaunokki:hasTimeOfStory", "skos:prefLabel", "sch:isbn", "dce:description"]
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']

# %%
## loop and save results into a dictionary
stats2 = {c:{v:"" for v in variables} for c in classes}


for c in classes:
    print (c)
    for v in variables:
        Q_ = Q.replace("class", c) # set the wanted class
        Q_ = Q_.replace("kaunokki:teema", v)  # loop through all variables
        sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
        sparql.setQuery(PREFIXES + Q_)
        sparql.setReturnFormat(JSON)
        sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
        results3 = sparql.query().convert()

        vars = results3['head']['vars']
        result = results3["results"]["bindings"][0]["result"]["value"] 
        print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
        stats2[c][v] = result
# Out:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>
# Query returned 1 result: 0.581436077057793345008757
# Query returned 1 result: 0.987740805604203152364273
# Query returned 1 result: 0.8756567425569176882662
# Query returned 1 result: 0.978984238178633975481611
# Query returned 1 result: 0.033274956217162872154116
# Query returned 1 result: 0.059544658493870402802102
# Query returned 1 result: 0.171628721541155866900175
# Query returned 1 result: 0.996497373029772329246935
# Query returned 1 result: 0.970227670753064798598949
# Query returned 1 result: 0.014010507880910683012259
# Query returned 1 result: 0.996497373029772329246935
# Query returned 1 result: 0.014010507880910683012259
# Query returned 1 result: 0.297723292469352014010508
# Query returned 1 result: 0.362521891418563922942207
# <http://www.yso.fi/onto/kaunokki#essee>
# Query returned 1 result: 0.452950558213716108452951
# Query returned 1 result: 0.972886762360446570972887
# Query returned 1 result: 0.824561403508771929824561
# Query returned 1 result: 0.842105263157894736842105
# Query returned 1 result: 0.036682615629984051036683
# Query returned 1 result: 0.188197767145135566188198
# Query returned 1 result: 0.055821371610845295055821
# Query returned 1 result: 0.961722488038277511961722
# Query returned 1 result: 0.909090909090909090909091
# Query returned 1 result: 0.020733652312599681020734
# Query returned 1 result: 0.976076555023923444976077
# Query returned 1 result: 0.019138755980861244019139
# Query returned 1 result: 0.403508771929824561403509
# Query returned 1 result: 0.334928229665071770334928
# <http://www.yso.fi/onto/kaunokki#kansanruno>
# Query returned 1 result: 0.666666666666666666666667
# Query returned 1 result: 0.890243902439024390243902
# Query returned 1 result: 0.869918699186991869918699
# Query returned 1 result: 0.93902439024390243902439
# Query returned 1 result: 0.085365853658536585365854
# Query returned 1 result: 0.089430894308943089430894
# Query returned 1 result: 0.25203252032520325203252
# Query returned 1 result: 0.983739837398373983739837
# Query returned 1 result: 0.849593495934959349593496
# Query returned 1 result: 0.012195121951219512195122
# Query returned 1 result: 0.995934959349593495934959
# Query returned 1 result: 0.004065040650406504065041
# Query returned 1 result: 0.646341463414634146341463
# Query returned 1 result: 0.62601626016260162601626
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>
# Query returned 1 result: 0.977272727272727272727273
# Query returned 1 result: 1.0
# Query returned 1 result: 0.931818181818181818181818
# Query returned 1 result: 1.0
# Query returned 1 result: 0.022727272727272727272727
# Query returned 1 result: 0.5
# Query returned 1 result: 0.113636363636363636363636
# Query returned 1 result: 1.0
# Query returned 1 result: 1.0
# Query returned 1 result: 1.0
# Query returned 1 result: 1.0
# Query returned 1 result: 0.0
# Query returned 1 result: 1.0
# Query returned 1 result: 1.0
# <http://www.yso.fi/onto/kaunokki#kokoomateos>
# Query returned 1 result: 0.694057724957555178268251
# Query returned 1 result: 0.933106960950764006791171
# Query returned 1 result: 0.851612903225806451612903
# Query returned 1 result: 0.905602716468590831918506
# Query returned 1 result: 0.06213921901528013582343
# Query returned 1 result: 0.114431239388794567062818
# Query returned 1 result: 0.279796264855687606112054
# Query returned 1 result: 0.940577249575551782682513
# Query returned 1 result: 0.912054329371816638370119
# Query returned 1 result: 0.004414261460101867572156
# Query returned 1 result: 0.971477079796264855687606
# Query returned 1 result: 0.003395585738539898132428
# Query returned 1 result: 0.624108658743633276740238
# Query returned 1 result: 0.452292020373514431239389
# <http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>
# Query returned 1 result: 0.860759493670886075949367
# Query returned 1 result: 1.0
# Query returned 1 result: 0.949367088607594936708861
# Query returned 1 result: 0.848101265822784810126582
# Query returned 1 result: 0.088607594936708860759494
# Query returned 1 result: 0.354430379746835443037975
# Query returned 1 result: 0.075949367088607594936709
# Query returned 1 result: 1.0
# Query returned 1 result: 1.0
# Query returned 1 result: 0.34177215189873417721519
# Query returned 1 result: 1.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.898734177215189873417722
# Query returned 1 result: 0.746835443037974683544304
# <http://www.yso.fi/onto/kaunokki#kuunnelma>
# Query returned 1 result: 0.967948717948717948717949
# Query returned 1 result: 1.0
# Query returned 1 result: 0.99358974358974358974359
# Query returned 1 result: 0.974358974358974358974359
# Query returned 1 result: 0.019230769230769230769231
# Query returned 1 result: 0.038461538461538461538462
# Query returned 1 result: 0.057692307692307692307692
# Query returned 1 result: 0.99358974358974358974359
# Query returned 1 result: 0.99358974358974358974359
# Query returned 1 result: 0.057692307692307692307692
# Query returned 1 result: 1.0
# Query returned 1 result: 0.00641025641025641025641
# Query returned 1 result: 0.955128205128205128205128
# Query returned 1 result: 0.820512820512820512820513
# <http://www.yso.fi/onto/kaunokki#kuvakirjat>
# Query returned 1 result: 0.268335757323914398504052
# Query returned 1 result: 0.939227093289008934136713
# Query returned 1 result: 0.382661541658009557448577
# Query returned 1 result: 0.68860378142530646166632
# Query returned 1 result: 0.007895283606897984624974
# Query returned 1 result: 0.005350093496779555370871
# Query returned 1 result: 0.104716393102015375025971
# Query returned 1 result: 0.811032619987533762725951
# Query returned 1 result: 0.94945979638479119052566
# Query returned 1 result: 0.002389362144192811136505
# Query returned 1 result: 0.997558695200498649490962
# Query returned 1 result: 0.000311655931851236235196
# Query returned 1 result: 0.042852690629544982339497
# Query returned 1 result: 0.298462497402867234573031
# <http://www.yso.fi/onto/kaunokki#kasikirjoitus>
# Query returned 1 result: 0.907894736842105263157895
# Query returned 1 result: 0.960526315789473684210526
# Query returned 1 result: 0.986842105263157894736842
# Query returned 1 result: 0.960526315789473684210526
# Query returned 1 result: 0.131578947368421052631579
# Query returned 1 result: 0.342105263157894736842105
# Query returned 1 result: 0.118421052631578947368421
# Query returned 1 result: 1.0
# Query returned 1 result: 0.986842105263157894736842
# Query returned 1 result: 0.171052631578947368421053
# Query returned 1 result: 0.960526315789473684210526
# Query returned 1 result: 0.092105263157894736842105
# Query returned 1 result: 0.973684210526315789473684
# Query returned 1 result: 0.828947368421052631578947
# <http://www.yso.fi/onto/kaunokki#novellikokoelma>
# Query returned 1 result: 0.69540727902946273830156
# Query returned 1 result: 0.963027151935297515886771
# Query returned 1 result: 0.87954939341421143847487
# Query returned 1 result: 0.959994222992489890236857
# Query returned 1 result: 0.037694974003466204506066
# Query returned 1 result: 0.088388214904679376083189
# Query returned 1 result: 0.115395725014442518775274
# Query returned 1 result: 0.944107452339688041594454
# Query returned 1 result: 0.915222414789139225880994
# Query returned 1 result: 0.00158867706528018486424
# Query returned 1 result: 0.951617562102830733679954
# Query returned 1 result: 0.000866551126516464471404
# Query returned 1 result: 0.588099364529173887926054
# Query returned 1 result: 0.36669555170421721548238
# <http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>
# Query returned 1 result: 0.932141066354671569446766
# Query returned 1 result: 0.993505408180320431699339
# Query returned 1 result: 0.954872137723550058499081
# Query returned 1 result: 0.977650963444043838494783
# Query returned 1 result: 0.120699123707647859411189
# Query returned 1 result: 0.435066020391108139729233
# Query returned 1 result: 0.00575439936964255867816
# Query returned 1 result: 0.976361595950430983023328
# Query returned 1 result: 0.987106325063871445285452
# Query returned 1 result: 0.974761825171318736419856
# Query returned 1 result: 0.994030706048088632076598
# Query returned 1 result: 0.000071631527422936415081
# Query returned 1 result: 0.997540650891812516415558
# Query returned 1 result: 0.96671521692414221245911
# <http://www.yso.fi/onto/kaunokki#naytelma>
# Query returned 1 result: 0.782653766413268832066344
# Query returned 1 result: 0.956461644782308223911541
# Query returned 1 result: 0.872840359364201796821009
# Query returned 1 result: 0.912923289564616447823082
# Query returned 1 result: 0.041465100207325501036628
# Query returned 1 result: 0.247408431237042156185211
# Query returned 1 result: 0.01451278507256392536282
# Query returned 1 result: 0.928472702142363510711818
# Query returned 1 result: 0.95680718728403593642018
# Query returned 1 result: 0.072909467864547339322737
# Query returned 1 result: 0.958880442294402211472011
# Query returned 1 result: 0.008293020041465100207326
# Query returned 1 result: 0.859364201796821008984105
# Query returned 1 result: 0.7885279889426399447132
# <http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>
# Query returned 1 result: 0.807962529274004683840749
# Query returned 1 result: 0.976580796252927400468384
# Query returned 1 result: 0.892271662763466042154567
# Query returned 1 result: 0.918032786885245901639344
# Query returned 1 result: 0.053864168618266978922717
# Query returned 1 result: 0.168618266978922716627635
# Query returned 1 result: 0.072599531615925058548009
# Query returned 1 result: 0.969555035128805620608899
# Query returned 1 result: 0.967213114754098360655738
# Query returned 1 result: 0.009367681498829039812646
# Query returned 1 result: 0.988290398126463700234192
# Query returned 1 result: 0.007025761124121779859485
# Query returned 1 result: 0.648711943793911007025761
# Query returned 1 result: 0.386416861826697892271663
# <http://www.yso.fi/onto/kaunokki#pakina>
# Query returned 1 result: 0.679970972423802612481858
# Query returned 1 result: 0.968069666182873730043541
# Query returned 1 result: 0.868650217706821480406386
# Query returned 1 result: 0.961538461538461538461538
# Query returned 1 result: 0.0246734397677793904209
# Query returned 1 result: 0.126269956458635703918723
# Query returned 1 result: 0.013788098693759071117562
# Query returned 1 result: 0.968795355587808417997097
# Query returned 1 result: 0.92960812772133526850508
# Query returned 1 result: 0.009433962264150943396226
# Query returned 1 result: 0.94194484760522496371553
# Query returned 1 result: 0.000725689404934687953556
# Query returned 1 result: 0.729317851959361393323657
# Query returned 1 result: 0.540638606676342525399129
# <http://seco.tkk.fi/saha3/kirjasampo/Pakinat>
# Query returned 1 result: 0.848739495798319327731092
# Query returned 1 result: 0.957983193277310924369748
# Query returned 1 result: 0.974789915966386554621849
# Query returned 1 result: 0.99159663865546218487395
# Query returned 1 result: 0.00840336134453781512605
# Query returned 1 result: 0.226890756302521008403361
# Query returned 1 result: 0.016806722689075630252101
# Query returned 1 result: 0.983193277310924369747899
# Query returned 1 result: 0.99159663865546218487395
# Query returned 1 result: 0.957983193277310924369748
# Query returned 1 result: 0.983193277310924369747899
# Query returned 1 result: 0.00840336134453781512605
# Query returned 1 result: 1.0
# Query returned 1 result: 0.857142857142857142857143
# <http://www.yso.fi/onto/kaunokki#romaani>
# Query returned 1 result: 0.294329711715952873548979
# Query returned 1 result: 0.910008795946431447366791
# Query returned 1 result: 0.407202765148230280355307
# Query returned 1 result: 0.537110221880845897496252
# Query returned 1 result: 0.003245828119773535351033
# Query returned 1 result: 0.108462691559608022894238
# Query returned 1 result: 0.0017715779432351738748
# Query returned 1 result: 0.710563807777598830510784
# Query returned 1 result: 0.679369169588324929694372
# Query returned 1 result: 0.000706153445904929446599
# Query returned 1 result: 0.757553983572640890001115
# Query returned 1 result: 0.00024777313891401033214
# Query returned 1 result: 0.358948946344726768171063
# Query returned 1 result: 0.265365031776905065721825
# <http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>
# Query returned 1 result: 0.696045489790643577151719
# Query returned 1 result: 0.974993538382010855518222
# Query returned 1 result: 0.925239079865598345825795
# Query returned 1 result: 0.980421297492892220211941
# Query returned 1 result: 0.026815714654949599379685
# Query returned 1 result: 0.156888084776428017575601
# Query returned 1 result: 0.031338847247350736624451
# Query returned 1 result: 0.935642284828120961488757
# Query returned 1 result: 0.965430343758077022486431
# Query returned 1 result: 0.001550788317394675626777
# Query returned 1 result: 0.996252261566296200568622
# Query returned 1 result: 0.000452313259240113724477
# Query returned 1 result: 0.438550012923235978288964
# Query returned 1 result: 0.465494959937968467304213
# <http://www.yso.fi/onto/kaunokki#runo>
# Query returned 1 result: 0.910853415473817720601558
# Query returned 1 result: 0.996557347345533611161442
# Query returned 1 result: 0.988041311831853596666063
# Query returned 1 result: 0.994564232650842543939119
# Query returned 1 result: 0.052545751041855408588512
# Query returned 1 result: 0.691067222322884580539953
# Query returned 1 result: 0.057075557166153288639246
# Query returned 1 result: 0.996376155100561695959413
# Query returned 1 result: 0.997463308570393187171589
# Query returned 1 result: 0.996557347345533611161442
# Query returned 1 result: 0.999818807755028084797971
# Query returned 1 result: 0.047109983692697952527632
# Query returned 1 result: 1.0
# Query returned 1 result: 0.316180467475992027541221
# <http://seco.tkk.fi/saha3/kirjasampo/Sadut>
# Query returned 1 result: 0.979874691475223087146383
# Query returned 1 result: 0.988798177330548699449402
# Query returned 1 result: 0.942915005379406366685653
# Query returned 1 result: 0.990949939877222960572116
# Query returned 1 result: 0.061831529650022150496804
# Query returned 1 result: 0.13701664451616986266692
# Query returned 1 result: 0.258084931333459907600785
# Query returned 1 result: 0.997088791848617176128093
# Query returned 1 result: 0.998607683058034301626479
# Query returned 1 result: 0.972027086893234605404721
# Query returned 1 result: 0.999746851465097145750269
# Query returned 1 result: 0.000316435668628567812164
# Query returned 1 result: 0.988165305993291563825074
# Query returned 1 result: 0.943041579646857793810518
# <http://www.yso.fi/onto/kaunokki#sarjakuva>
# Query returned 1 result: 0.495444387141138043665119
# Query returned 1 result: 0.953068592057761732851986
# Query returned 1 result: 0.579680247550283651366684
# Query returned 1 result: 0.538937596699329551315111
# Query returned 1 result: 0.030256145779611483582603
# Query returned 1 result: 0.068935877600137527935362
# Query returned 1 result: 0.093003266288464844421523
# Query returned 1 result: 0.815712566615093690905965
# Query returned 1 result: 0.864706893587760013752794
# Query returned 1 result: 0.001031459515214027849407
# Query returned 1 result: 0.947567474643286917655149
# Query returned 1 result: 0.000687639676809351899605
# Query returned 1 result: 0.246690734055354993983153
# Query returned 1 result: 0.247894103489771359807461
# <http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>
# Query returned 1 result: 0.795148247978436657681941
# Query returned 1 result: 0.998652291105121293800539
# Query returned 1 result: 0.811320754716981132075472
# Query returned 1 result: 0.77897574123989218328841
# Query returned 1 result: 0.02964959568733153638814
# Query returned 1 result: 0.780323450134770889487871
# Query returned 1 result: 0.134770889487870619946092
# Query returned 1 result: 0.919137466307277628032345
# Query returned 1 result: 0.991913746630727762803235
# Query returned 1 result: 0.884097035040431266846361
# Query returned 1 result: 0.987870619946091644204852
# Query returned 1 result: 0.0
# Query returned 1 result: 0.994609164420485175202156
# Query returned 1 result: 0.815363881401617250673854
# <http://www.yso.fi/onto/kaunokki#satu>
# Query returned 1 result: 0.760285617137028221693302
# Query returned 1 result: 0.965997959877592655559334
# Query returned 1 result: 0.734784087045222713362802
# Query returned 1 result: 0.893573614416865011900714
# Query returned 1 result: 0.02142128527711662699762
# Query returned 1 result: 0.018021081264875892553553
# Query returned 1 result: 0.267256035362121727303638
# Query returned 1 result: 0.938456307378442706562394
# Query returned 1 result: 0.916695001700102006120367
# Query returned 1 result: 0.00204012240734444066644
# Query returned 1 result: 0.99693981638898333900034
# Query returned 1 result: 0.00204012240734444066644
# Query returned 1 result: 0.308058483509010540632438
# Query returned 1 result: 0.562393743624617477048623
# <http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>
# Query returned 1 result: 0.288196218702095043433827
# Query returned 1 result: 0.968829841594276954522228
# Query returned 1 result: 0.734287174246295350025549
# Query returned 1 result: 0.798671435871231476750128
# Query returned 1 result: 0.124680633622892181911088
# Query returned 1 result: 0.101686254471129279509453
# Query returned 1 result: 0.062851303014818599897803
# Query returned 1 result: 0.954522227899846704138988
# Query returned 1 result: 0.727133367399080224833929
# Query returned 1 result: 0.014818599897802759325498
# Query returned 1 result: 0.910066428206438426162494
# Query returned 1 result: 0.01430761369443025038324
# Query returned 1 result: 0.451711803781297904956566
# Query returned 1 result: 0.428206438426162493612672
# <http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>
# Query returned 1 result: 0.535616438356164383561644
# Query returned 1 result: 0.935616438356164383561644
# Query returned 1 result: 0.752054794520547945205479
# Query returned 1 result: 0.978082191780821917808219
# Query returned 1 result: 0.021917808219178082191781
# Query returned 1 result: 0.072602739726027397260274
# Query returned 1 result: 0.342465753424657534246575
# Query returned 1 result: 0.952054794520547945205479
# Query returned 1 result: 0.894520547945205479452055
# Query returned 1 result: 0.001369863013698630136986
# Query returned 1 result: 0.990410958904109589041096
# Query returned 1 result: 0.0
# Query returned 1 result: 0.509589041095890410958904
# Query returned 1 result: 0.456164383561643835616438

# %%
# to dataframe
statdf = pd.DataFrame()
classlabels = list(data["class_label"])
n=0
for k,v in stats2.items():
    #print(v)
    ix =classes.index(k)
    key = classlabels[ix]
    temp = pd.DataFrame(data=v, index= [key])
    statdf=pd.concat([statdf,temp])

# %%
# change column names to remove the "kaunokki:" part
columnnames = list(statdf.columns)
columnnames = [c.split(":")[1] for c in columnnames]

statdf.columns= columnnames
statdf.head()
# Out:
#                                           teema                    asiasana  \
# aforismikokoelmat    0.581436077057793345008757  0.987740805604203152364273
# esseekokoelmat       0.452950558213716108452951  0.972886762360446570972887
# kansanrunokokoelmat  0.666666666666666666666667  0.890243902439024390243902
# kansanrunot          0.977272727272727272727273                         1.0
# kokoomateokset       0.694057724957555178268251  0.933106960950764006791171
#
#                                         toimija                  paahenkilo  \
# aforismikokoelmat      0.8756567425569176882662  0.978984238178633975481611
# esseekokoelmat       0.824561403508771929824561  0.842105263157894736842105
# kansanrunokokoelmat  0.869918699186991869918699   0.93902439024390243902439
# kansanrunot          0.931818181818181818181818                         1.0
# kokoomateokset       0.851612903225806451612903  0.905602716468590831918506
#
#                                       alkukieli                       genre  \
# aforismikokoelmat    0.033274956217162872154116  0.059544658493870402802102
# esseekokoelmat       0.036682615629984051036683  0.188197767145135566188198
# kansanrunokokoelmat  0.085365853658536585365854  0.089430894308943089430894
# kansanrunot          0.022727272727272727272727                         0.5
# kokoomateokset        0.06213921901528013582343  0.114431239388794567062818
#
#                                          tekija                      paikka  \
# aforismikokoelmat    0.171628721541155866900175  0.996497373029772329246935
# esseekokoelmat       0.055821371610845295055821  0.961722488038277511961722
# kansanrunokokoelmat   0.25203252032520325203252  0.983739837398373983739837
# kansanrunot          0.113636363636363636363636                         1.0
# kokoomateokset       0.279796264855687606112054  0.940577249575551782682513
#
#                                      worldPlace                manifests_in  \
# aforismikokoelmat    0.970227670753064798598949  0.014010507880910683012259
# esseekokoelmat       0.909090909090909090909091  0.020733652312599681020734
# kansanrunokokoelmat  0.849593495934959349593496  0.012195121951219512195122
# kansanrunot                                 1.0                         1.0
# kokoomateokset       0.912054329371816638370119  0.004414261460101867572156
#
#                                  hasTimeOfStory                   prefLabel  \
# aforismikokoelmat    0.996497373029772329246935  0.014010507880910683012259
# esseekokoelmat       0.976076555023923444976077  0.019138755980861244019139
# kansanrunokokoelmat  0.995934959349593495934959  0.004065040650406504065041
# kansanrunot                                 1.0                         0.0
# kokoomateokset       0.971477079796264855687606  0.003395585738539898132428
#
#                                            isbn                 description
# aforismikokoelmat    0.297723292469352014010508  0.362521891418563922942207
# esseekokoelmat       0.403508771929824561403509  0.334928229665071770334928
# kansanrunokokoelmat  0.646341463414634146341463   0.62601626016260162601626
# kansanrunot                                 1.0                         1.0
# kokoomateokset       0.624108658743633276740238  0.452292020373514431239389

# %%
statdf=statdf.astype(float)
statdf = 1-statdf
#statdf.to_csv("../../output/results/annotation_stats.csv", sep="\t")
statdf.head()
# Out:
#                         teema  asiasana   toimija  paahenkilo  alkukieli  \
# aforismikokoelmat    0.418564  0.012259  0.124343    0.021016   0.966725
# esseekokoelmat       0.547049  0.027113  0.175439    0.157895   0.963317
# kansanrunokokoelmat  0.333333  0.109756  0.130081    0.060976   0.914634
# kansanrunot          0.022727  0.000000  0.068182    0.000000   0.977273
# kokoomateokset       0.305942  0.066893  0.148387    0.094397   0.937861
#
#                         genre    tekija    paikka  worldPlace  manifests_in  \
# aforismikokoelmat    0.940455  0.828371  0.003503    0.029772      0.985989
# esseekokoelmat       0.811802  0.944179  0.038278    0.090909      0.979266
# kansanrunokokoelmat  0.910569  0.747967  0.016260    0.150407      0.987805
# kansanrunot          0.500000  0.886364  0.000000    0.000000      0.000000
# kokoomateokset       0.885569  0.720204  0.059423    0.087946      0.995586
#
#                      hasTimeOfStory  prefLabel      isbn  description
# aforismikokoelmat          0.003503   0.985989  0.702277     0.637478
# esseekokoelmat             0.023923   0.980861  0.596491     0.665072
# kansanrunokokoelmat        0.004065   0.995935  0.353659     0.373984
# kansanrunot                0.000000   1.000000  0.000000     0.000000
# kokoomateokset             0.028523   0.996604  0.375891     0.547708

# %%
#statdf["class_count"]=class_count
statdf=statdf.set_index(class_count)

# %%
# add background gradient for visualization


neworder= ["tekija","prefLabel", "genre","teema", "asiasana", "paahenkilo","toimija","paikka", "worldPlace","isbn","hasTimeOfStory"]

statdf[neworder].style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_01d71_row0_col0, #T_01d71_row12_col2 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_01d71_row0_col1, #T_01d71_row11_col0, #T_01d71_row13_col0, #T_01d71_row22_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_01d71_row0_col2 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_01d71_row0_col3, #T_01d71_row19_col6 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_01d71_row0_col4, #T_01d71_row2_col7, #T_01d71_row8_col6, #T_01d71_row8_col8, #T_01d71_row10_col8, #T_01d71_row14_col7, #T_01d71_row14_col10, #T_01d71_row17_col6, #T_01d71_row18_col9, #T_01d71_row20_col10 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_01d71_row0_col5, #T_01d71_row3_col3, #T_01d71_row10_col5, #T_01d71_row12_col4, #T_01d71_row16_col5, #T_01d71_row18_col3, #T_01d71_row23_col5 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_01d71_row0_col6 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_01d71_row0_col7, #T_01d71_row0_col10, #T_01d71_row3_col4, #T_01d71_row3_col5, #T_01d71_row3_col7, #T_01d71_row3_col8, #T_01d71_row3_col9, #T_01d71_row3_col10, #T_01d71_row5_col4, #T_01d71_row5_col7, #T_01d71_row5_col8, #T_01d71_row5_col10, #T_01d71_row6_col4, #T_01d71_row6_col10, #T_01d71_row7_col10, #T_01d71_row8_col7, #T_01d71_row10_col9, #T_01d71_row14_col9, #T_01d71_row16_col10, #T_01d71_row17_col4, #T_01d71_row17_col7, #T_01d71_row17_col8, #T_01d71_row17_col9, #T_01d71_row17_col10, #T_01d71_row18_col7, #T_01d71_row18_col8, #T_01d71_row18_col10, #T_01d71_row20_col4, #T_01d71_row21_col10 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_01d71_row0_col8, #T_01d71_row4_col10, #T_01d71_row12_col7, #T_01d71_row13_col7, #T_01d71_row22_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_01d71_row0_col9 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_01d71_row1_col0, #T_01d71_row6_col0, #T_01d71_row17_col0 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_01d71_row1_col1, #T_01d71_row14_col0, #T_01d71_row21_col2 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_01d71_row1_col2 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_01d71_row1_col3, #T_01d71_row22_col9 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_01d71_row1_col4, #T_01d71_row1_col10, #T_01d71_row6_col5, #T_01d71_row8_col9, #T_01d71_row10_col7, #T_01d71_row14_col6, #T_01d71_row16_col4 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_01d71_row1_col5 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_01d71_row1_col6 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_01d71_row1_col7, #T_01d71_row9_col4, #T_01d71_row13_col5 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_01d71_row1_col8, #T_01d71_row8_col3, #T_01d71_row15_col4, #T_01d71_row22_col10 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_01d71_row1_col9 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_01d71_row2_col0 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_01d71_row2_col1, #T_01d71_row6_col1, #T_01d71_row7_col2, #T_01d71_row10_col0, #T_01d71_row12_col1 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_01d71_row2_col2, #T_01d71_row9_col2 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_01d71_row2_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_01d71_row2_col4 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_01d71_row2_col5, #T_01d71_row4_col7, #T_01d71_row7_col4, #T_01d71_row21_col7 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_01d71_row2_col6, #T_01d71_row13_col6 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_01d71_row2_col8, #T_01d71_row4_col6, #T_01d71_row5_col5, #T_01d71_row14_col3 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_01d71_row2_col9 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_01d71_row2_col10, #T_01d71_row6_col6, #T_01d71_row6_col7, #T_01d71_row6_col8, #T_01d71_row10_col4, #T_01d71_row10_col10, #T_01d71_row17_col5, #T_01d71_row20_col9 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_01d71_row3_col0, #T_01d71_row4_col2, #T_01d71_row9_col0 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_01d71_row3_col1, #T_01d71_row4_col1, #T_01d71_row5_col1, #T_01d71_row7_col1, #T_01d71_row9_col1, #T_01d71_row10_col1, #T_01d71_row13_col1, #T_01d71_row15_col0, #T_01d71_row15_col1, #T_01d71_row16_col1, #T_01d71_row18_col1, #T_01d71_row19_col1, #T_01d71_row20_col1, #T_01d71_row21_col1, #T_01d71_row23_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_01d71_row3_col2 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_01d71_row3_col6, #T_01d71_row4_col4, #T_01d71_row10_col3 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_01d71_row4_col0 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_01d71_row4_col3 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_01d71_row4_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_01d71_row4_col8, #T_01d71_row9_col8, #T_01d71_row11_col5, #T_01d71_row17_col3, #T_01d71_row21_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_01d71_row4_col9 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_01d71_row5_col0 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_01d71_row5_col2 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_01d71_row5_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_01d71_row5_col6, #T_01d71_row6_col9, #T_01d71_row7_col8, #T_01d71_row9_col10, #T_01d71_row10_col6, #T_01d71_row11_col4, #T_01d71_row11_col8, #T_01d71_row19_col4, #T_01d71_row22_col7, #T_01d71_row23_col7 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_01d71_row5_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_01d71_row6_col2 {
#   background-color: #034267;
#   color: #f1f1f1;
# }
# #T_01d71_row6_col3, #T_01d71_row12_col8, #T_01d71_row13_col4, #T_01d71_row16_col8, #T_01d71_row21_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_01d71_row7_col0, #T_01d71_row22_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_01d71_row7_col3, #T_01d71_row21_col0 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_01d71_row7_col5, #T_01d71_row17_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_01d71_row7_col6 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_01d71_row7_col7, #T_01d71_row20_col6 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_01d71_row7_col9 {
#   background-color: #034369;
#   color: #f1f1f1;
# }
# #T_01d71_row8_col0 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_01d71_row8_col1, #T_01d71_row19_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_01d71_row8_col2, #T_01d71_row23_col0 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_01d71_row8_col4, #T_01d71_row8_col5, #T_01d71_row8_col10, #T_01d71_row9_col5, #T_01d71_row11_col10, #T_01d71_row14_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_01d71_row9_col3, #T_01d71_row16_col3 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_01d71_row9_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_01d71_row9_col7, #T_01d71_row13_col10, #T_01d71_row18_col6, #T_01d71_row19_col10 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_01d71_row9_col9 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_01d71_row10_col2 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_01d71_row11_col1, #T_01d71_row14_col1 {
#   background-color: #023a5b;
#   color: #f1f1f1;
# }
# #T_01d71_row11_col2, #T_01d71_row19_col9 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_01d71_row11_col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_01d71_row11_col6 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_01d71_row11_col7, #T_01d71_row13_col8 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_01d71_row11_col9 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_01d71_row12_col0, #T_01d71_row23_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_01d71_row12_col3 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_01d71_row12_col5, #T_01d71_row20_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_01d71_row12_col6, #T_01d71_row21_col5, #T_01d71_row23_col8 {
#   background-color: #efe9f3;
#   color: #000000;
# }

# %%
# the annotations show which aspects are important for each class
## e.g. worldplace usually not relevant for poems
## has time of story for novels might indicate historical writing (or sci-fi)
## worldplace is still surprisingly low for novels -- does this reduce my analysis too much?

# %%
# Finnish novels
# Translated novels
# Authors
decs=[(1970,1981),(1980,1991),(1990,2001),(2000,2011),(2010,2021)]
decs=[(str(t[0]),str(t[1])) for t in decs]

# loop through all classes
Q_fi = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin> . # if you want only literature originally written in Finnish
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
   
   
   OPTIONAL { 
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin> . # if you want only literature originally written in Finnish
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year .
    # ?year skos:prefLabel ?yearuri
    FILTER(xsd:integer(?yearuri) > 1970)   
    FILTER(xsd:integer(?yearuri) < 1981)  
    FILTER NOT EXISTS  { ?teos kaunokki:teema ?teema }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
variables = ["kaunokki:teema", "kaunokki:asiasana", "kaunokki:toimija" , "kaunokki:paahenkilo", "kaunokki:alkukieli", "kaunokki:genre", 
             "kaunokki:tekija", "kaunokki:paikka", "kaunokki:worldPlace", "kaunokki:manifests_in", "kaunokki:hasTimeOfStory", "skos:prefLabel", "sch:isbn", "dce:description"]

## loop and save results into a dictionary
stats2 = {c:{v:"" for v in variables} for c in ["fi","tr","au"]}


#for c in classes:
   # print (c)
for v in variables:
    stats2["fi"][v]={}
    for dec in decs:
        print(dec)
        #Q_ = Q.replace("class", c) # set the wanted class
        Q_ = Q_fi.replace("kaunokki:teema", v)  # loop through all variables
        #Q_ = Q_.replace("197", dec)  # loop through all variables
        Q_ = Q_.replace("1970", dec[0])  # loop through all variables
        Q_ = Q_.replace("1981", dec[1])  # loop through all variables
        sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
        sparql.setQuery(PREFIXES + Q_)
        sparql.setReturnFormat(JSON)
        sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
        results3 = sparql.query().convert()

        vars = results3['head']['vars']
        result = results3["results"]["bindings"][0]["result"]["value"] 
        print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
        
        stats2["fi"][v][dec] = result
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']
# ('1970', '1981')
# Query returned 1 result: 0.260416666666666666666667
# ('1980', '1991')
# Query returned 1 result: 0.247692307692307692307692
# ('1990', '2001')
# Query returned 1 result: 0.206839032527105921601334
# ('2000', '2011')
# Query returned 1 result: 0.120123998966675277706019
# ('2010', '2021')
# Query returned 1 result: 0.14695970695970695970696
# ('1970', '1981')
# Query returned 1 result: 0.842447916666666666666667
# ('1980', '1991')
# Query returned 1 result: 0.94358974358974358974359
# ('1990', '2001')
# Query returned 1 result: 0.906171809841534612176814
# ('2000', '2011')
# Query returned 1 result: 0.894600878326013949883751
# ('2010', '2021')
# Query returned 1 result: 0.944029304029304029304029
# ('1970', '1981')
# Query returned 1 result: 0.458984375
# ('1980', '1991')
# Query returned 1 result: 0.532820512820512820512821
# ('1990', '2001')
# Query returned 1 result: 0.460383653044203502919099
# ('2000', '2011')
# Query returned 1 result: 0.308447429604753293722552
# ('2010', '2021')
# Query returned 1 result: 0.285860805860805860805861
# ('1970', '1981')
# Query returned 1 result: 0.703776041666666666666667
# ('1980', '1991')
# Query returned 1 result: 0.747692307692307692307692
# ('1990', '2001')
# Query returned 1 result: 0.639699749791492910758966
# ('2000', '2011')
# Query returned 1 result: 0.527253939550503745802118
# ('2010', '2021')
# Query returned 1 result: 0.321904761904761904761905
# ('1970', '1981')
# Query returned 1 result: 0.0
# ('1980', '1991')
# Query returned 1 result: 0.0
# ('1990', '2001')
# Query returned 1 result: 0.0
# ('2000', '2011')
# Query returned 1 result: 0.0
# ('2010', '2021')
# Query returned 1 result: 0.0
# ('1970', '1981')
# Query returned 1 result: 0.091796875
# ('1980', '1991')
# Query returned 1 result: 0.064102564102564102564103
# ('1990', '2001')
# Query returned 1 result: 0.040867389491242702251877
# ('2000', '2011')
# Query returned 1 result: 0.037974683544303797468354
# ('2010', '2021')
# Query returned 1 result: 0.055677655677655677655678
# ('1970', '1981')
# Query returned 1 result: 0.001953125
# ('1980', '1991')
# Query returned 1 result: 0.001025641025641025641026
# ('1990', '2001')
# Query returned 1 result: 0.002502085070892410341952
# ('2000', '2011')
# Query returned 1 result: 0.002583311805734952208732
# ('2010', '2021')
# Query returned 1 result: 0.002344322344322344322344
# ('1970', '1981')
# Query returned 1 result: 0.69921875
# ('1980', '1991')
# Query returned 1 result: 0.749743589743589743589744
# ('1990', '2001')
# Query returned 1 result: 0.710175145954962468723937
# ('2000', '2011')
# Query returned 1 result: 0.619478171015241539653836
# ('2010', '2021')
# Query returned 1 result: 0.59326007326007326007326
# ('1970', '1981')
# Query returned 1 result: 0.529947916666666666666667
# ('1980', '1991')
# Query returned 1 result: 0.784615384615384615384615
# ('1990', '2001')
# Query returned 1 result: 0.620517097581317764804003
# ('2000', '2011')
# Query returned 1 result: 0.746835443037974683544304
# ('2010', '2021')
# Query returned 1 result: 0.649963369963369963369963
# ('1970', '1981')
# Query returned 1 result: 0.0
# ('1980', '1991')
# Query returned 1 result: 0.0
# ('1990', '2001')
# Query returned 1 result: 0.0
# ('2000', '2011')
# Query returned 1 result: 0.0
# ('2010', '2021')
# Query returned 1 result: 0.0
# ('1970', '1981')
# Query returned 1 result: 0.445963541666666666666667
# ('1980', '1991')
# Query returned 1 result: 0.557948717948717948717949
# ('1990', '2001')
# Query returned 1 result: 0.570892410341951626355296
# ('2000', '2011')
# Query returned 1 result: 0.719194006716610694910876
# ('2010', '2021')
# Query returned 1 result: 0.828278388278388278388278
# ('1970', '1981')
# Query returned 1 result: 0.0
# ('1980', '1991')
# Query returned 1 result: 0.0
# ('1990', '2001')
# Query returned 1 result: 0.0
# ('2000', '2011')
# Query returned 1 result: 0.0
# ('2010', '2021')
# Query returned 1 result: 0.0
# ('1970', '1981')
# Query returned 1 result: 0.3984375
# ('1980', '1991')
# Query returned 1 result: 0.212820512820512820512821
# ('1990', '2001')
# Query returned 1 result: 0.190575479566305254378649
# ('2000', '2011')
# Query returned 1 result: 0.214673211056574528545595
# ('2010', '2021')
# Query returned 1 result: 0.073113553113553113553114
# ('1970', '1981')
# Query returned 1 result: 0.408203125
# ('1980', '1991')
# Query returned 1 result: 0.312307692307692307692308
# ('1990', '2001')
# Query returned 1 result: 0.202668890742285237698082
# ('2000', '2011')
# Query returned 1 result: 0.123740635494704210798243
# ('2010', '2021')
# Query returned 1 result: 0.07706959706959706959707

# %%
stats2
df_stats_fi=stats2["fi"]

# %%
# Translated novels
decs=[(1970,1981),(1980,1991),(1990,2001),(2000,2011),(2010,2021)]
decs=[(str(t[0]),str(t[1])) for t in decs]
# loop through all classes
Q_fi = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli != <http://lexvo.org/id/iso639-3/fin>)
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
   
   
   OPTIONAL { 
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli != <http://lexvo.org/id/iso639-3/fin>)
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
    FILTER NOT EXISTS  { ?teos kaunokki:teema ?teema }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
variables = ["kaunokki:teema", "kaunokki:asiasana", "kaunokki:toimija" , "kaunokki:paahenkilo", "kaunokki:alkukieli", "kaunokki:genre", 
             "kaunokki:tekija", "kaunokki:paikka", "kaunokki:worldPlace", "kaunokki:manifests_in", "kaunokki:hasTimeOfStory", "skos:prefLabel", "sch:isbn", "dce:description"]

## loop and save results into a dictionary
#stats2 = {c:{v:"" for v in variables} for c in ["fi","tr"]}


#for c in classes:
   # print (c)
for v in variables:
    stats2["tr"][v]={}
    for dec in decs:
        #Q_ = Q.replace("class", c) # set the wanted class
        Q_ = Q_fi.replace("kaunokki:teema", v)  # loop through all variables
        #Q_ = Q_.replace("197", dec)  # loop through all variables
        Q_ = Q_.replace("1970", dec[0])  # loop through all variables
        Q_ = Q_.replace("1981", dec[1])  # loop through all variables
        sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
        sparql.setQuery(PREFIXES + Q_)
        sparql.setReturnFormat(JSON)
        sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
        results3 = sparql.query().convert()

        vars = results3['head']['vars']
        result = results3["results"]["bindings"][0]["result"]["value"] 
        print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
        
        stats2["tr"][v][dec] = result
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']
# Query returned 1 result: 0.274173806609547123623011
# Query returned 1 result: 0.163583605368153790351832
# Query returned 1 result: 0.146735617323852617970265
# Query returned 1 result: 0.065078314581954555482021
# Query returned 1 result: 0.110729613733905579399142
# Query returned 1 result: 0.82374541003671970624235
# Query returned 1 result: 0.878853826623141095393544
# Query returned 1 result: 0.848416289592760180995475
# Query returned 1 result: 0.856827707919699977939554
# Query returned 1 result: 0.895493562231759656652361
# Query returned 1 result: 0.373317013463892288861689
# Query returned 1 result: 0.473340587595212187159956
# Query returned 1 result: 0.409502262443438914027149
# Query returned 1 result: 0.169424222369291859695566
# Query returned 1 result: 0.191201716738197424892704
# Query returned 1 result: 0.614443084455324357405141
# Query returned 1 result: 0.558215451577801958650707
# Query returned 1 result: 0.395281189398836457659987
# Query returned 1 result: 0.342598720494153981910435
# Query returned 1 result: 0.237768240343347639484979
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.024887800897592819257446
# Query returned 1 result: 0.027566195139644541167936
# Query returned 1 result: 0.006787330316742081447964
# Query returned 1 result: 0.003088462386940216192367
# Query returned 1 result: 0.002789699570815450643777
# Query returned 1 result: 0.0
# Query returned 1 result: 0.001450852375770765324628
# Query returned 1 result: 0.000969618616677440206852
# Query returned 1 result: 0.00110302228105007721156
# Query returned 1 result: 0.002360515021459227467811
# Query returned 1 result: 0.681354549163606691146471
# Query returned 1 result: 0.700036271309394269133116
# Query returned 1 result: 0.702003878474466709760827
# Query returned 1 result: 0.558349878667549084491507
# Query returned 1 result: 0.522103004291845493562232
# Query returned 1 result: 0.489596083231334149326805
# Query returned 1 result: 0.575625680087051142546246
# Query returned 1 result: 0.442792501616031027795734
# Query returned 1 result: 0.592322964923891462607545
# Query returned 1 result: 0.492918454935622317596567
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.492452060383516931864545
# Query returned 1 result: 0.463547334058759521218716
# Query returned 1 result: 0.468002585649644473173885
# Query returned 1 result: 0.731965585704831237590999
# Query returned 1 result: 0.799141630901287553648069
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.0
# Query returned 1 result: 0.314157486740106079151367
# Query returned 1 result: 0.178454842219804134929271
# Query returned 1 result: 0.126050420168067226890756
# Query returned 1 result: 0.075887932936245312155306
# Query returned 1 result: 0.014163090128755364806867
# Query returned 1 result: 0.403916768665850673194614
# Query returned 1 result: 0.216902430177729416031919
# Query returned 1 result: 0.143826761473820297349709
# Query returned 1 result: 0.041914846679902934039268
# Query returned 1 result: 0.031115879828326180257511

# %%
df_stats_tr=stats2["tr"]

# %%
# translated authors

# loop through all classes
Q_fi = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:tekija ?author .
    
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli != <http://lexvo.org/id/iso639-3/fin>)
    
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
   
   
   OPTIONAL { 
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli != <http://lexvo.org/id/iso639-3/fin>)
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
    # ?teos kaunokki:tekija ?author .
    FILTER NOT EXISTS  { ?author kaunokki:teema ?teema }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
variables = ["foaf:gender", "kaunokki:kansallisuus", "kaunokki:aidinkieli" , "kaunokki:timeOfBirth", "kaunokki:hasLivedIn", "kaunokki:placeOfBirth", 
             ]

## loop and save results into a dictionary
#stats2 = {c:{v:"" for v in variables} for c in ["fi","tr","au"]}


#for c in classes:
   # print (c)
for v in variables:
    stats2["au"][v]={}
    for dec in decs:
        #Q_ = Q.replace("class", c) # set the wanted class
        Q_ = Q_fi.replace("kaunokki:teema", v)  # loop through all variables
        #Q_ = Q_.replace("197", dec)  # loop through all variables
        Q_ = Q_.replace("1970", dec[0])  # loop through all variables
        Q_ = Q_.replace("1981", dec[1])  # loop through all variables
        sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
        sparql.setQuery(PREFIXES + Q_)
        sparql.setReturnFormat(JSON)
        sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
        results3 = sparql.query().convert()

        vars = results3['head']['vars']
        result = results3["results"]["bindings"][0]["result"]["value"] 
        print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
        
        stats2["au"][v][dec] = result
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']
# Query returned 1 result: 0.049367605059159526723786
# Query returned 1 result: 0.034144569560479476934254
# Query returned 1 result: 0.02491103202846975088968
# Query returned 1 result: 0.014134275618374558303887
# Query returned 1 result: 0.008388900838890083889008
# Query returned 1 result: 0.073439412484700122399021
# Query returned 1 result: 0.088267344714856520159826
# Query returned 1 result: 0.061145260433516661274668
# Query returned 1 result: 0.036660777385159010600707
# Query returned 1 result: 0.027747902774790277479028
# Query returned 1 result: 0.004079967360261117911057
# Query returned 1 result: 0.00181620050853614239012
# Query returned 1 result: 0.0
# Query returned 1 result: 0.000662544169611307420495
# Query returned 1 result: 0.003226500322650032265003
# Query returned 1 result: 0.196246430028559771521828
# Query returned 1 result: 0.201961496549219033781329
# Query returned 1 result: 0.197023616952442575218376
# Query returned 1 result: 0.182420494699646643109541
# Query returned 1 result: 0.252527425252742525274253
# Query returned 1 result: 0.934312525499796001631987
# Query returned 1 result: 0.914275335997094079186342
# Query returned 1 result: 0.868650922031704949854416
# Query returned 1 result: 0.748895759717314487632509
# Query returned 1 result: 0.738653473865347386534739
# Query returned 1 result: 0.491228070175438596491228
# Query returned 1 result: 0.499818379949146385760988
# Query returned 1 result: 0.396958912973147848592688
# Query returned 1 result: 0.380742049469964664310954
# Query returned 1 result: 0.467627446762744676274468

# %%
# Finnish authors

# loop through all classes
Q_fi = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:tekija ?author .
    
    # ?teos kaunokki:alkukieli ?alkukieli . # original language Finnish
    FILTER(?alkukieli = <http://lexvo.org/id/iso639-3/fin>)
    
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
   
   
   OPTIONAL { 
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli = <http://lexvo.org/id/iso639-3/fin>)
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
    # ?teos kaunokki:tekija ?author .
    FILTER NOT EXISTS  { ?author kaunokki:teema ?teema }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
variables = ["foaf:gender", "kaunokki:kansallisuus", "kaunokki:aidinkieli" , "kaunokki:timeOfBirth", "kaunokki:hasLivedIn", "kaunokki:placeOfBirth", 
             ]

## loop and save results into a dictionary
#stats2 = {c:{v:"" for v in variables} for c in ["fi","tr","au","au_fi"]}

stats2["au_fi"]={}

decs=[(1970,1981),(1980,1991),(1990,2001),(2000,2011),(2010,2021)]
decs=[(str(t[0]),str(t[1])) for t in decs]

#for c in classes:
   # print (c)
for v in variables:
    stats2["au_fi"][v]={}
    for dec in decs:
        #Q_ = Q.replace("class", c) # set the wanted class
        Q_ = Q_fi.replace("kaunokki:teema", v)  # loop through all variables
        Q_ = Q_.replace("1970", dec[0])  # loop through all variables
        Q_ = Q_.replace("1981", dec[1])  # loop through all variables
        sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
        sparql.setQuery(PREFIXES + Q_)
        sparql.setReturnFormat(JSON)
        sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
        results3 = sparql.query().convert()

        vars = results3['head']['vars']
        result = results3["results"]["bindings"][0]["result"]["value"] 
        print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
        
        stats2["au_fi"][v][dec] = result
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']
# Query returned 1 result: 0.004566210045662100456621
# Query returned 1 result: 0.010780287474332648870637
# Query returned 1 result: 0.005434782608695652173913
# Query returned 1 result: 0.010101010101010101010101
# Query returned 1 result: 0.018945513291232192686151
# Query returned 1 result: 0.000652315720808871493803
# Query returned 1 result: 0.002566735112936344969199
# Query returned 1 result: 0.005016722408026755852843
# Query returned 1 result: 0.005439005439005439005439
# Query returned 1 result: 0.003231017770597738287561
# Query returned 1 result: 0.0
# Query returned 1 result: 0.00051334702258726899384
# Query returned 1 result: 0.00041806020066889632107
# Query returned 1 result: 0.000777000777000777000777
# Query returned 1 result: 0.000587457776472316052284
# Query returned 1 result: 0.107632093933463796477495
# Query returned 1 result: 0.164271047227926078028747
# Query returned 1 result: 0.21404682274247491638796
# Query returned 1 result: 0.197876197876197876197876
# Query returned 1 result: 0.343222205903950653546776
# Query returned 1 result: 0.515329419439008480104371
# Query returned 1 result: 0.461498973305954825462012
# Query returned 1 result: 0.39214046822742474916388
# Query returned 1 result: 0.287749287749287749287749
# Query returned 1 result: 0.380232045821706564840652
# Query returned 1 result: 0.158512720156555772994129
# Query returned 1 result: 0.223819301848049281314168
# Query returned 1 result: 0.266304347826086956521739
# Query returned 1 result: 0.275058275058275058275058
# Query returned 1 result: 0.496548685563225143192833

# %%
stats2["tr"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 stats2["tr"]
#
# KeyError: 'tr'

# %%
print(len(variables))
# Out:
# 6

# %%
# translated authors

# loop through all classes
Q_fi = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    #?teos kaunokki:tekija ?author .
    
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli != <http://lexvo.org/id/iso639-3/fin>)
    
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
   
   
   OPTIONAL { 
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli ?alkukieli . # original language not Finnish
    FILTER(?alkukieli != <http://lexvo.org/id/iso639-3/fin>)
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
    #?teos kaunokki:tekija ?author .
    FILTER EXISTS  { ?julkaisu kaunokki:hasPublisher ?publisher }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
pubvariables = ["kaunokki:julkaisija"
             ]

## loop and save results into a dictionary
#stats2 = {c:{v:"" for v in variables} for c in ["fi","tr","au"]}

pubstats={"fi":{},"tr":{}}
#for c in classes:
   # print (c)
#for v in variables:
#    stats2["au"][v]={}
for dec in decs:
    #Q_ = Q.replace("class", c) # set the wanted class
    #Q_ = Q_fi.replace("kaunokki:teema", v)  # loop through all variables
    Q_ = Q_fi.replace("1970", dec[0])  # loop through all variables
    Q_ = Q_.replace("1981", dec[1])  # loop through all variables
    sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
    sparql.setQuery(PREFIXES + Q_)
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
    results3 = sparql.query().convert()

    vars = results3['head']['vars']
    result = results3["results"]["bindings"][0]["result"]["value"] 
    print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)

    pubstats["tr"][dec] = result
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']
# Query returned 1 result: 0.992656058751529987760098
# Query returned 1 result: 0.986942328618063112078346
# Query returned 1 result: 0.987718164188752424046542
# Query returned 1 result: 0.992278844032649459519082
# Query returned 1 result: 0.998927038626609442060086

# %%
# Finnish publications
Q_fi = """
SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) 
    WHERE

{
    
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    #?teos kaunokki:tekija ?author .
    
    # ?teos kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin> .
    
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
   
   
   OPTIONAL { 
    # ?teos a kaunokki:romaani ; kaunokki:manifests_in ?julkaisu. # teos is a novel
    # ?teos kaunokki:alkukieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:kieli <http://lexvo.org/id/iso639-3/fin> .
    # ?julkaisu kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearuri .
    FILTER(xsd:integer(?yearuri) > 1970)     FILTER(xsd:integer(?yearuri) < 1981)
    #?teos kaunokki:tekija ?author .
    FILTER EXISTS  { ?julkaisu kaunokki:hasPublisher ?publisher }
    BIND(?teos AS ?teemateos) 
    
  } 
} 
}
"""

classes = list(data["bookclass"])
classes = [c.n3() for c in classes]
print(classes)
pubvariables = ["kaunokki:julkaisija"
             ]

## loop and save results into a dictionary
#stats2 = {c:{v:"" for v in variables} for c in ["fi","tr","au"]}

#pubstats={"fi":{},"tr":{}}
#for c in classes:
   # print (c)
#for v in variables:
#    stats2["au"][v]={}
#    stats2["au"][v]={}
for dec in decs:
    #Q_ = Q.replace("class", c) # set the wanted class
    #Q_ = Q_fi.replace("kaunokki:teema", v)  # loop through all variables
    Q_ = Q_fi.replace("1970", dec[0])  # loop through all variables
    Q_ = Q_.replace("1981", dec[1])  # loop through all variables
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
    results3 = sparql.query().convert()

    vars = results3['head']['vars']
    result = results3["results"]["bindings"][0]["result"]["value"] 
    print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)

    pubstats["fi"][dec] = result
# Out:
# ['<http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat>', '<http://www.yso.fi/onto/kaunokki#essee>', '<http://www.yso.fi/onto/kaunokki#kansanruno>', '<http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot>', '<http://www.yso.fi/onto/kaunokki#kokoomateos>', '<http://seco.tkk.fi/saha3/kirjasampo/Kuunnelmat>', '<http://www.yso.fi/onto/kaunokki#kuunnelma>', '<http://www.yso.fi/onto/kaunokki#kuvakirjat>', '<http://www.yso.fi/onto/kaunokki#kasikirjoitus>', '<http://www.yso.fi/onto/kaunokki#novellikokoelma>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237530959951>', '<http://www.yso.fi/onto/kaunokki#naytelma>', '<http://seco.tkk.fi/saha3/u0a6a963d-2b8c-40ee-b213-560653d9806b>', '<http://www.yso.fi/onto/kaunokki#pakina>', '<http://seco.tkk.fi/saha3/kirjasampo/Pakinat>', '<http://www.yso.fi/onto/kaunokki#romaani>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>', '<http://www.yso.fi/onto/kaunokki#runo>', '<http://seco.tkk.fi/saha3/kirjasampo/Sadut>', '<http://www.yso.fi/onto/kaunokki#sarjakuva>', '<http://seco.tkk.fi/saha3/kirjasampo/Sarjakuvat>', '<http://www.yso.fi/onto/kaunokki#satu>', '<http://www.seco.tkk.fi/applications/saha#Instance_ID1237984819752>', '<http://seco.tkk.fi/saha3/u578baac2-f84b-4906-af9e-99f85ce645a4>']
# Query returned 1 result: 0.998927038626609442060086
# Query returned 1 result: 0.998927038626609442060086
# Query returned 1 result: 0.998927038626609442060086
# Query returned 1 result: 0.998927038626609442060086
# Query returned 1 result: 0.998927038626609442060086

# %%
# make df

# %%
novelvariables=  ["kaunokki:teema",   "kaunokki:genre", 
             "kaunokki:tekija", "kaunokki:paikka", "kaunokki:worldPlace"]

# %%
tr_df=pd.DataFrame(stats2["tr"])
fi_df=pd.DataFrame(stats2["fi"])

# %%
fi_df[novelvariables]=fi_df[novelvariables].apply(pd.to_numeric)

# %%
tr_df[novelvariables]=tr_df[novelvariables].apply(pd.to_numeric)

# %%
fi_df[novelvariables]=1-fi_df[novelvariables]

# %%
tr_df[novelvariables]=1-tr_df[novelvariables]

# %%
fi_df2=fi_df[novelvariables].T
tr_df2=tr_df[novelvariables].T

# %%
#fi_df2.values==tr_df2.values
fi_df2
# Out:
#                          1970      1980      1990      2000      2010
#                          1981      1991      2001      2011      2021
# kaunokki:teema       0.739583  0.752308  0.793161  0.879876  0.853040
# kaunokki:genre       0.908203  0.935897  0.959133  0.962025  0.944322
# kaunokki:tekija      0.998047  0.998974  0.997498  0.997417  0.997656
# kaunokki:paikka      0.300781  0.250256  0.289825  0.380522  0.406740
# kaunokki:worldPlace  0.470052  0.215385  0.379483  0.253165  0.350037

# %%
pub_fi=pd.DataFrame(pubstats)
#pubstats
collist=list(pub_fi.columns)
pub_fi[collist]=pub_fi[collist].apply(pd.to_numeric )

# %%
pub_fi
# Out:
#                  fi        tr
# 1970 1981  0.998927  0.992656
# 1980 1991  0.998927  0.986942
# 1990 2001  0.998927  0.987718
# 2000 2011  0.998927  0.992279
# 2010 2021  0.998927  0.998927

# %%
fi_df2=pd.concat([fi_df2,pub_fi.T.head(1)])
tr_df2=pd.concat([tr_df2,pub_fi.T.tail(1)])

# %%
tr_au=pd.DataFrame(stats2["au"])
fi_au=pd.DataFrame(stats2["au_fi"])

# %%
fi_au[variables]=fi_au[variables].apply(pd.to_numeric)
tr_au[variables]=tr_au[variables].apply(pd.to_numeric)

# %%
fi_au[variables]=1-fi_au[variables]
tr_au[variables]=1-tr_au[variables]

# %%
tr_au[variables].T
# Out:
#                            1970      1980      1990      2000      2010
#                            1981      1991      2001      2011      2021
# foaf:gender            0.950632  0.965855  0.975089  0.985866  0.991611
# kaunokki:kansallisuus  0.926561  0.911733  0.938855  0.963339  0.972252
# kaunokki:aidinkieli    0.995920  0.998184  1.000000  0.999337  0.996773
# kaunokki:timeOfBirth   0.803754  0.798039  0.802976  0.817580  0.747473
# kaunokki:hasLivedIn    0.065687  0.085725  0.131349  0.251104  0.261347
# kaunokki:placeOfBirth  0.508772  0.500182  0.603041  0.619258  0.532373

# %%
corr = fi_au[variables].T
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)#.style.background_gradient()
# Out:
# /tmp/ipykernel_17337/2045886001.py:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)#.style.background_gradient()
# <style type="text/css">
# #T_706ab_row0_col0, #T_706ab_row0_col2, #T_706ab_row1_col2, #T_706ab_row1_col3 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_706ab_row0_col1, #T_706ab_row0_col3 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_706ab_row0_col4 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_706ab_row1_col0, #T_706ab_row2_col0, #T_706ab_row2_col1, #T_706ab_row2_col2, #T_706ab_row2_col3, #T_706ab_row2_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_706ab_row1_col1, #T_706ab_row1_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_706ab_row3_col0 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_706ab_row3_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_706ab_row3_col2 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_706ab_row3_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_706ab_row3_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_706ab_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_706ab_row4_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_706ab_row4_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_706ab_row4_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_706ab_row4_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_706ab_row5_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_706ab_row5_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_706ab_row5_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_706ab_row5_col3 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_706ab_row5_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_706ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_706ab_level0_col0" class="col_heading level0 col0" >1970</th>
#       <th id="T_706ab_level0_col1" class="col_heading level0 col1" >1980</th>
#       <th id="T_706ab_level0_col2" class="col_heading level0 col2" >1990</th>
#       <th id="T_706ab_level0_col3" class="col_heading level0 col3" >2000</th>
#       <th id="T_706ab_level0_col4" class="col_heading level0 col4" >2010</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_706ab_level1_col0" class="col_heading level1 col0" >1981</th>
#       <th id="T_706ab_level1_col1" class="col_heading level1 col1" >1991</th>
#       <th id="T_706ab_level1_col2" class="col_heading level1 col2" >2001</th>
#       <th id="T_706ab_level1_col3" class="col_heading level1 col3" >2011</th>
#       <th id="T_706ab_level1_col4" class="col_heading level1 col4" >2021</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_706ab_level0_row0" class="row_heading level0 row0" >foaf:gender</th>
#       <td id="T_706ab_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_706ab_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_706ab_row0_col2" class="data row0 col2" >0.99</td>
#       <td id="T_706ab_row0_col3" class="data row0 col3" >0.99</td>
#       <td id="T_706ab_row0_col4" class="data row0 col4" >0.98</td>
#     </tr>
#     <tr>
#       <th id="T_706ab_level0_row1" class="row_heading level0 row1" >kaunokki:kansallisuus</th>
#       <td id="T_706ab_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_706ab_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_706ab_row1_col2" class="data row1 col2" >0.99</td>
#       <td id="T_706ab_row1_col3" class="data row1 col3" >0.99</td>
#       <td id="T_706ab_row1_col4" class="data row1 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_706ab_level0_row2" class="row_heading level0 row2" >kaunokki:aidinkieli</th>
#       <td id="T_706ab_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_706ab_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_706ab_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_706ab_row2_col3" class="data row2 col3" >1.00</td>
#       <td id="T_706ab_row2_col4" class="data row2 col4" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_706ab_level0_row3" class="row_heading level0 row3" >kaunokki:timeOfBirth</th>
#       <td id="T_706ab_row3_col0" class="data row3 col0" >0.89</td>
#       <td id="T_706ab_row3_col1" class="data row3 col1" >0.84</td>
#       <td id="T_706ab_row3_col2" class="data row3 col2" >0.79</td>
#       <td id="T_706ab_row3_col3" class="data row3 col3" >0.80</td>
#       <td id="T_706ab_row3_col4" class="data row3 col4" >0.66</td>
#     </tr>
#     <tr>
#       <th id="T_706ab_level0_row4" class="row_heading level0 row4" >kaunokki:hasLivedIn</th>
#       <td id="T_706ab_row4_col0" class="data row4 col0" >0.48</td>
#       <td id="T_706ab_row4_col1" class="data row4 col1" >0.54</td>
#       <td id="T_706ab_row4_col2" class="data row4 col2" >0.61</td>
#       <td id="T_706ab_row4_col3" class="data row4 col3" >0.71</td>
#       <td id="T_706ab_row4_col4" class="data row4 col4" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_706ab_level0_row5" class="row_heading level0 row5" >kaunokki:placeOfBirth</th>
#       <td id="T_706ab_row5_col0" class="data row5 col0" >0.84</td>
#       <td id="T_706ab_row5_col1" class="data row5 col1" >0.78</td>
#       <td id="T_706ab_row5_col2" class="data row5 col2" >0.73</td>
#       <td id="T_706ab_row5_col3" class="data row5 col3" >0.72</td>
#       <td id="T_706ab_row5_col4" class="data row5 col4" >0.50</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(tr_df2.style.set_precision(3).to_latex())
# Out:
# \begin{tabular}{lrrrrr}
#  & 1970 & 1980 & 1990 & 2000 & 2010 \\
#  & 1981 & 1991 & 2001 & 2011 & 2021 \\
# kaunokki:teema & 0.726 & 0.836 & 0.853 & 0.935 & 0.889 \\
# kaunokki:genre & 0.975 & 0.972 & 0.993 & 0.997 & 0.997 \\
# kaunokki:tekija & 1.000 & 0.999 & 0.999 & 0.999 & 0.998 \\
# kaunokki:paikka & 0.319 & 0.300 & 0.298 & 0.442 & 0.478 \\
# kaunokki:worldPlace & 0.510 & 0.424 & 0.557 & 0.408 & 0.507 \\
# tr & 0.993 & 0.987 & 0.988 & 0.992 & 0.999 \\
# \end{tabular}
# /tmp/ipykernel_17337/2248165489.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   print(tr_df2.style.set_precision(3).to_latex())

# %%
#fi_df==tr_df

print(fi_df2.style.set_precision(3).to_latex())
# Out:
# \begin{tabular}{lrrrrr}
#  & 1970 & 1980 & 1990 & 2000 & 2010 \\
#  & 1981 & 1991 & 2001 & 2011 & 2021 \\
# kaunokki:teema & 0.740 & 0.752 & 0.793 & 0.880 & 0.853 \\
# kaunokki:genre & 0.908 & 0.936 & 0.959 & 0.962 & 0.944 \\
# kaunokki:tekija & 0.998 & 0.999 & 0.997 & 0.997 & 0.998 \\
# kaunokki:paikka & 0.301 & 0.250 & 0.290 & 0.381 & 0.407 \\
# kaunokki:worldPlace & 0.470 & 0.215 & 0.379 & 0.253 & 0.350 \\
# fi & 0.999 & 0.999 & 0.999 & 0.999 & 0.999 \\
# \end{tabular}
# /tmp/ipykernel_17337/3122039662.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   print(fi_df2.style.set_precision(3).to_latex())

# %%
# save
#statdf.to_csv("../../output/results/annotation_stats.csv", sep="\t")
import dataframe_image as dfi
#dfi.export(statdf[neworder].style.background_gradient(axis=None)  ,"../../output/figures/annotation_stats_v2.png")

# %% [markdown]
# ### development per year for novels

# %%
## query group by year to get yearly development of the proportion of annotated works VS no annotation (per class)
Q = """
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?teemateos) AS ?novalue) (SAMPLE(?yearLabel) AS ?vuosi) 
    WHERE

{
    # ?teos a ?class .
    # ?teos kaunokki:manifests_in ?pub .
    # ?pub kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearLabel  .
    FILTER(xsd:integer(?yearLabel) > 1899) # from the beginning of the 20th century

   OPTIONAL { 
    
    # ?teos a ?class .
     # ?teos kaunokki:manifests_in ?pub .
    # ?pub kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearLabel  .
    FILTER(xsd:integer(?yearLabel) > 1899)                      
    FILTER NOT EXISTS  { ?teos kaunokki:teema ?teema }
    BIND(?teos AS ?teemateos) 
    
  }
} GROUP BY ?year 

"""


variables = ["kaunokki:teema", "kaunokki:asiasana", "kaunokki:toimija" , "kaunokki:paahenkilo", "kaunokki:alkukieli", "kaunokki:genre", 
             "kaunokki:tekija", "kaunokki:paikka", "kaunokki:worldPlace", "kaunokki:manifests_in", "kaunokki:hasTimeOfStory", "skos:prefLabel", "sch:isbn", "dce:description"]

# %%
stats2 = {c:{v:"" for v in variables} for c in classes}


# loop again 

for c in classes:
    #print (c)
    for v in variables:
        #print(v)
        Q_ = Q.replace("?class", c)
        Q_ = Q_.replace("kaunokki:teema", v)
        print(c,v)
        sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
        sparql.setQuery(PREFIXES + Q_)
        sparql.setReturnFormat(JSON)
        sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
        results3 = sparql.query().convert()

        vars = results3['head']['vars']
        values= [list(i.values() ) for i in results3["results"]["bindings"]]
        #print(values[0][0]["value"])

        result = [[i[0]["value"], values[e][1]["value"], values[e][2]["value"]] for e,i in enumerate(values)]
        #result = [results3["results"]["bindings"][0]["total"]["value"] , results3["results"]["bindings"][0]["novalue"]["value"] , results3["results"]["bindings"][0]["vuosi"]["value"] ]
        print("Query returned {} results:".format(len(results3["results"]["bindings"])))
        stats2[c][v] = result
# Out:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:teema
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:asiasana
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:toimija
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:paahenkilo
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:alkukieli
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:genre
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:tekija
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:paikka
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:worldPlace
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:manifests_in
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> kaunokki:hasTimeOfStory
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> skos:prefLabel
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> sch:isbn
# Query returned 76 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Aforismikokoelmat> dce:description
# Query returned 76 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:teema
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:asiasana
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:toimija
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:paahenkilo
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:alkukieli
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:genre
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:tekija
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:paikka
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:worldPlace
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:manifests_in
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> kaunokki:hasTimeOfStory
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> skos:prefLabel
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> sch:isbn
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#essee> dce:description
# Query returned 83 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:teema
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:asiasana
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:toimija
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:paahenkilo
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:alkukieli
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:genre
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:tekija
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:paikka
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:worldPlace
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:manifests_in
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> kaunokki:hasTimeOfStory
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> skos:prefLabel
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> sch:isbn
# Query returned 91 results:
# <http://www.yso.fi/onto/kaunokki#kansanruno> dce:description
# Query returned 91 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:teema
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:asiasana
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:toimija
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:paahenkilo
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:alkukieli
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:genre
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:tekija
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:paikka
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:worldPlace
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:manifests_in
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> kaunokki:hasTimeOfStory
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> skos:prefLabel
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> sch:isbn
# Query returned 0 results:
# <http://seco.tkk.fi/saha3/kirjasampo/Kansanrunot> dce:description
# Query returned 0 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:teema
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:asiasana
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:toimija
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:paahenkilo
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:alkukieli
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:genre
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:tekija
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:paikka
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:worldPlace
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:manifests_in
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> kaunokki:hasTimeOfStory
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> skos:prefLabel
# Query returned 122 results:
# <http://www.yso.fi/onto/kaunokki#kokoomateos> sch:isbn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [48], in <cell line: 6>()
#      15 sparql.setReturnFormat(JSON)
#      16 sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
# ---> 17 results3 = sparql.query().convert()
#      19 vars = results3['head']['vars']
#      20 values= [list(i.values() ) for i in results3["results"]["bindings"]]
#
# File ~/kirjasampo/benv/lib/python3.8/site-packages/SPARQLWrapper/Wrapper.py:960, in SPARQLWrapper.query(self)
#     942 def query(self) -> "QueryResult":
#     943     """
#     944     Execute the query.
#     945     Exceptions can be raised if either the URI is wrong or the HTTP sends back an error (this is also the
#    (...)
#     958     :rtype: :class:`QueryResult` instance
#     959     """
# --> 960     return QueryResult(self._query())
#
# File ~/kirjasampo/benv/lib/python3.8/site-packages/SPARQLWrapper/Wrapper.py:926, in SPARQLWrapper._query(self)
#     924         response = urlopener(request, timeout=self.timeout)
#     925     else:
# --> 926         response = urlopener(request)
#     927     return response, self.returnFormat
#     928 except urllib.error.HTTPError as e:
#
# File /usr/lib/python3.8/urllib/request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220 else:
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.8/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     522     req = meth(req)
#     524 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525 response = self._open(req, data)
#     527 # post-process response
#     528 meth_name = protocol+"_response"
#
# File /usr/lib/python3.8/urllib/request.py:542, in OpenerDirector._open(self, req, data)
#     539     return result
#     541 protocol = req.type
# --> 542 result = self._call_chain(self.handle_open, protocol, protocol +
#     543                           '_open', req)
#     544 if result:
#     545     return result
#
# File /usr/lib/python3.8/urllib/request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     500 for handler in handlers:
#     501     func = getattr(handler, meth_name)
# --> 502     result = func(*args)
#     503     if result is not None:
#     504         return result
#
# File /usr/lib/python3.8/urllib/request.py:1383, in HTTPHandler.http_open(self, req)
#    1382 def http_open(self, req):
# -> 1383     return self.do_open(http.client.HTTPConnection, req)
#
# File /usr/lib/python3.8/urllib/request.py:1358, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1356     except OSError as err: # timeout error
#    1357         raise URLError(err)
# -> 1358     r = h.getresponse()
#    1359 except:
#    1360     h.close()
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
stats2[c]

# %%
# plot one class you want

## novels as an example
c="<http://www.yso.fi/onto/kaunokki#romaani>"
#c="<http://www.yso.fi/onto/kaunokki#novellikokoelma>"
#c="<http://www.seco.tkk.fi/applications/saha#Instance_ID1238070215614>" # runokokoelmat
#plt.style.use('seaborn-husl') #'seaborn-dark-palette'

import seaborn as sns

#set_theme() 
sns.set_theme(style="white",palette="PuOr_r")
# https://medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f

fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7,ax8)) = plt.subplots(2, 4, figsize=(16,6), sharex=True)
axlist=[ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8]
plotkeys=['kaunokki:teema', 'kaunokki:asiasana', 'kaunokki:toimija', 'kaunokki:paahenkilo', 'kaunokki:genre',"kaunokki:paikka", 'kaunokki:worldPlace','kaunokki:hasTimeOfStory']
novels = stats2[c]
for i,k in enumerate(plotkeys):
    tempdf = pd.DataFrame(stats2[c][k], columns=["all", "no_val","year"])
    tempdf["year"]= pd.to_numeric(tempdf["year"])
    tempdf["no_val"]= pd.to_numeric(tempdf["no_val"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    #tempdf=tempdf[tempdf["all"] >10]
    tempdf =tempdf.sort_values(by="year")
    #x= tempdf["year"]
    #y1 = tempdf["all"]
    #y2 = tempdf["no_val"]
    #axlist[i].title.set_text(k)
    #axlist[i].plot(x,y1, label = "all books")
    #axlist[i].plot(x,y2, label="not annotated")
    
    tempdf["yes_val"] = tempdf["all"]-tempdf["no_val"]
    tempdf=tempdf[tempdf["all"] >10]
    tempdf=tempdf[tempdf["year"]<2022]
    tempdf =tempdf.sort_values(by="year")
    x= tempdf["year"]
    y1 = tempdf["yes_val"]
    y2 = tempdf["no_val"]
    axlist[i].title.set_text(k)
    #axlist[i].plot(x,y1, label = "all books")
    #axlist[i].plot(x,y2, label="not annotated")
    axlist[i].stackplot(x,y1, y2, labels=['Annotated','Not annotated'])
    axlist[i].legend(loc='upper left')
    

#ax1.plot(
    

#plt.savefig("fig/novels_annotations.png", format="png")
plt.tight_layout()
plt.savefig("../../output/figures/novels_annotations_2v2.png", format="png")
plt.show()

# %%
# perustiedot

plotkeys = [ "kaunokki:alkukieli", "kaunokki:manifests_in",
             "kaunokki:tekija", "skos:prefLabel", "sch:isbn", "dce:description"]

fig, ((ax1, ax2, ax3), (ax5, ax6, ax7)) = plt.subplots(2, 3, figsize=(12,6), sharex=True)
axlist=[ax1,ax2,ax3,ax5,ax6,ax7]

#plotkeys=['kaunokki:teema', 'kaunokki:asiasana', 'kaunokki:toimija', 'kaunokki:paahenkilo', 'kaunokki:genre',"kaunokki:paikka", 'kaunokki:worldPlace','kaunokki:hasTimeOfStory']
novels = stats2[c]
for i,k in enumerate(plotkeys):
    tempdf = pd.DataFrame(stats2[c][k], columns=["all", "no_val","year"])
    tempdf["year"]= pd.to_numeric(tempdf["year"])
    tempdf["no_val"]= pd.to_numeric(tempdf["no_val"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    #tempdf=tempdf[tempdf["all"] >10]
    #tempdf =tempdf.sort_values(by="year")
    #x= tempdf["year"]
    #y1 = tempdf["all"]
    #y2 = tempdf["no_val"]
    #axlist[i].title.set_text(k)
    #axlist[i].plot(x,y1, label = "all books")
    #axlist[i].plot(x,y2, label="not annotated")
    
    
    
    tempdf["yes_val"] = tempdf["all"]-tempdf["no_val"]
    tempdf=tempdf[tempdf["all"] >10]
    tempdf=tempdf[tempdf["year"]<2022]
    tempdf =tempdf.sort_values(by="year")
    x= tempdf["year"]
    y1 = tempdf["yes_val"]
    y2 = tempdf["no_val"]
    axlist[i].title.set_text(k)
    #axlist[i].plot(x,y1, label = "all books")
    #axlist[i].plot(x,y2, label="not annotated")
    axlist[i].stackplot(x,y1, y2, labels=['Annotated','Not annotated'])
    axlist[i].legend(loc='upper left')
    


plt.tight_layout()
plt.savefig("../../output/figures/novels_annotations_1v2.png", format="png")
plt.show()

# %%
# kieli, publisher, kansikuva, on ensimmainenversio (approx = suomalainen kirja)
## query group by year to get yearly development of the proportion of annotated works VS no annotation (per class)
Q = """
SELECT (COUNT(DISTINCT ?teos) AS ?total) (COUNT(DISTINCT ?kieliteos) AS ?novalue) (SAMPLE(?yearLabel) AS ?vuosi) 
    WHERE

{
    # ?teos a kaunokki:romaani .
    # ?teos kaunokki:manifests_in ?pub .
    # ?pub kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearLabel  .
    FILTER(xsd:integer(?yearLabel) > 1899) # from the beginning of the 20th century

   OPTIONAL { 
    
    # ?teos a kaunokki:romaani .
     # ?teos kaunokki:manifests_in ?pub .
    # ?pub kaunokki:ilmestymisvuosi ?year . ?year skos:prefLabel ?yearLabel  .
    FILTER(xsd:integer(?yearLabel) > 1899)                      
    FILTER NOT EXISTS  { ?pub kaunokki:kieli ?kieli }
    BIND(?teos AS ?kieliteos) 
    
  }
} GROUP BY ?year 

"""


variables = ["kaunokki:kieli", "kaunokki:onEnsimmainenVersio","kaunokki:hasPublisher","kaunokki:kansikuva","kaunokki:sivuLkm"]

# %%
pubstats = {v:"" for v in variables}
for v in variables:
    #print(v)
    #Q_ = Q.replace("?class", c)
    Q_ = Q.replace("kaunokki:kieli", v)
    print(v)
    sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
    sparql.setQuery(PREFIXES + Q_)
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
    results3 = sparql.query().convert()

    vars = results3['head']['vars']
    values= [list(i.values() ) for i in results3["results"]["bindings"]]
    #print(values[0][0]["value"])

    result = [[i[0]["value"], values[e][1]["value"], values[e][2]["value"]] for e,i in enumerate(values)]
    #result = [results3["results"]["bindings"][0]["total"]["value"] , results3["results"]["bindings"][0]["novalue"]["value"] , results3["results"]["bindings"][0]["vuosi"]["value"] ]
    print("Query returned {} results:".format(len(results3["results"]["bindings"])))
    pubstats[v] = result

# %%
variables = ["kaunokki:kieli", "kaunokki:onEnsimmainenVersio","kaunokki:hasPublisher","kaunokki:kansikuva","kaunokki:sivuLkm"]
fig, ((ax1, ax2, ax3), (ax4,ax5, ax6)) = plt.subplots(2, 3, figsize=(12,6), sharex=True)
axlist=[ax1,ax2,ax3,ax4,ax5,ax6]
#plotkeys=['kaunokki:teema', 'kaunokki:asiasana', 'kaunokki:toimija', 'kaunokki:paahenkilo', 'kaunokki:genre',"kaunokki:paikka", 'kaunokki:worldPlace','kaunokki:hasTimeOfStory']

for i,k in enumerate(variables):
    tempdf = pd.DataFrame(pubstats[k], columns=["all", "no_val","year"])
    tempdf["year"]= pd.to_numeric(tempdf["year"])
    tempdf["no_val"]= pd.to_numeric(tempdf["no_val"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    tempdf["yes_val"] = tempdf["all"]-tempdf["no_val"]
    tempdf=tempdf[tempdf["all"] >10]
    tempdf=tempdf[tempdf["year"]<2022]
    tempdf =tempdf.sort_values(by="year")
    x= tempdf["year"]
    y1 = tempdf["yes_val"]
    y2 = tempdf["no_val"]
    axlist[i].title.set_text(k)
    #axlist[i].plot(x,y1, label = "all books")
    #axlist[i].plot(x,y2, label="not annotated")
    axlist[i].stackplot(x,y1, y2, labels=['Annotated','Not annotated'])
    
    
    axlist[i].legend(loc='upper left')

#ax1.plot(
    

#plt.savefig("fig/novels_annotations.png", format="png")
plt.tight_layout()
plt.savefig("../../output/figures/pubs_annotations.png", format="png")
plt.show()

# %%
# combine all into one

#novels.update(pubstats)

variables = [ 
    "kaunokki:tekija", "kaunokki:alkukieli","kaunokki:kieli","skos:prefLabel", 
    "sch:isbn", "kaunokki:hasPublisher","kaunokki:onEnsimmainenVersio","kaunokki:sivuLkm",
    'kaunokki:teema', 'kaunokki:asiasana', 'kaunokki:toimija', 'kaunokki:paahenkilo', 
    'kaunokki:genre',"kaunokki:paikka", 'kaunokki:worldPlace','kaunokki:hasTimeOfStory']
fig, ((ax1, ax2, ax3, ax4), (ax5, ax6, ax7,ax8), (ax9,ax10,ax11,ax12),(ax13,ax14,ax15,ax16)) = plt.subplots(4, 4, figsize=(16,12), sharex=True)
axlist=[ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12,ax13,ax14,ax15,ax16]
#plotkeys=['kaunokki:teema', 'kaunokki:asiasana', 'kaunokki:toimija', 'kaunokki:paahenkilo', 'kaunokki:genre',"kaunokki:paikka", 'kaunokki:worldPlace','kaunokki:hasTimeOfStory']

for i,k in enumerate(variables):
    tempdf = pd.DataFrame(novels[k], columns=["all", "no_val","year"])
    tempdf["year"]= pd.to_numeric(tempdf["year"])
    tempdf["no_val"]= pd.to_numeric(tempdf["no_val"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    tempdf["all"]= pd.to_numeric(tempdf["all"])
    tempdf["yes_val"] = tempdf["all"]-tempdf["no_val"]
    tempdf=tempdf[tempdf["all"] >10]
    tempdf=tempdf[tempdf["year"]<2022]
    tempdf =tempdf.sort_values(by="year")
    x= tempdf["year"]
    y1 = tempdf["yes_val"]
    y2 = tempdf["no_val"]
    axlist[i].title.set_text(k)
    #axlist[i].plot(x,y1, label = "all books")
    #axlist[i].plot(x,y2, label="not annotated")
    axlist[i].stackplot(x,y1, y2, labels=['Annotated','Not annotated'])
    
    
    axlist[i].legend(loc='upper left')

#ax1.plot(
    

#plt.savefig("fig/novels_annotations.png", format="png")
plt.tight_layout()
plt.savefig("../../output/figures/novels_annotations_combined.png", format="png")
plt.show()

# %% [markdown]
# ## People

# %%
# this chunk looks at who the people in KirjaSampo are

Q =""" 

SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?person) AS ?total) (COUNT(DISTINCT ?personInfo) AS ?novalue) 
    WHERE

{
    
    # ?person a foaf:Person . # all people
    
   OPTIONAL { 
    
    # ?person a foaf:Person .
    FILTER EXISTS  { ?person kaunokki:occupation ?info }
    BIND(?person AS ?personInfo) 
    
  } 
} 
}
"""

# %%
personvars=  "kaunokki:occupation kaunokki:kansallisuus foaf:gender kaunokki:timeOfBirth kaunokki:timeOfDeath kaunokki:placeOfBirth kaunokki:placeOfDeath kaunokki:hasLivedIn kaunokki:aidinkieli kaunokki:hasBiographicalInformation kaunokki:ownWords kaunokki:textSample kaunokki:hasWritten" #kaunokki:sameAs
personvars= personvars.split()
# loop
personstats = {}
for p in personvars:
    Q_ = Q.replace("kaunokki:occupation", p) # set the wanted variable
    
    sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
    sparql.setQuery(PREFIXES + Q_)
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
    results3 = sparql.query().convert()

    vars = results3['head']['vars']
    result = results3["results"]["bindings"][0]["result"]["value"] 
    print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
    personstats[p] = result

# %%
people=pd.DataFrame.from_dict(personstats,"index", columns=["hasValue"]).sort_values(by="hasValue", ascending=False).astype(float).round(4)
people

# %%
# do the same only looking at authors
Q =""" 

SELECT  ((?novalue/?total) AS ?result) WHERE {
SELECT (COUNT(DISTINCT ?person) AS ?total) (COUNT(DISTINCT ?personInfo) AS ?novalue) 
    WHERE

{
    
    # ?person a foaf:Person . # all people
    # ?person kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> .# kirjailijat
   OPTIONAL { 
    
    # ?person a foaf:Person .
    FILTER EXISTS  { ?person variable ?info }
    BIND(?person AS ?personInfo) 
    
  } 
} 
}
"""

personvars=  "kaunokki:kansallisuus foaf:gender kaunokki:timeOfBirth kaunokki:timeOfDeath kaunokki:placeOfBirth kaunokki:placeOfDeath kaunokki:hasLivedIn kaunokki:aidinkieli kaunokki:hasBiographicalInformation kaunokki:ownWords kaunokki:textSample kaunokki:hasWritten" #kaunokki:sameAs
personvars= personvars.split()
# loop
personstats = {}
for p in personvars:
    Q_ = Q.replace("variable", p) # set the wanted variable
    
    sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
    sparql.setQuery(PREFIXES + Q_)
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
    results3 = sparql.query().convert()

    vars = results3['head']['vars']
    result = results3["results"]["bindings"][0]["result"]["value"] 
    print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
    personstats[p] = result

# %%
# Only authors
Q =""" 
SELECT  ((?novalue/?total) AS ?result) ((?novaluefi/?totalfi) AS ?resultfi) WHERE {
SELECT (COUNT(DISTINCT ?person) AS ?total) (COUNT(DISTINCT ?personInfo) AS ?novalue) (COUNT(DISTINCT ?personfi) AS ?totalfi) (COUNT(DISTINCT ?personInfofi) AS ?novaluefi) 
    WHERE

{
 
    {
    # ?person a foaf:Person . # all people
    # ?person kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> . # kirjailijat
    
   OPTIONAL { 
    # ?person a foaf:Person .
    # ?person kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> . # kirjailijat
    FILTER EXISTS  { ?person variable ?info }
    BIND(?person AS ?personInfo) 
  	} 
    }
    UNION
    {
      # ?personfi a foaf:Person . # all people
    # ?personfi kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> . # kirjailijat
      # ?personfi kaunokki:kansallisuus <http://www.yso.fi/onto/koko/p35259>.
    
   OPTIONAL { 
    
    # ?personfi a foaf:Person .
    # ?personfi kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> . # kirjailijat
    # ?personfi kaunokki:kansallisuus <http://www.yso.fi/onto/koko/p35259>.
    FILTER EXISTS  { ?personfi variable ?infofi }
    BIND(?personfi AS ?personInfofi) 
    }
    }
  }
}
"""

personvars=  "kaunokki:kansallisuus foaf:gender kaunokki:timeOfBirth kaunokki:timeOfDeath kaunokki:placeOfBirth kaunokki:placeOfDeath kaunokki:hasLivedIn kaunokki:aidinkieli kaunokki:hasBiographicalInformation kaunokki:ownWords kaunokki:textSample kaunokki:hasWritten" #kaunokki:sameAs
personvars= personvars.split()
# loop
authors=pd.DataFrame()
for p in personvars:
    Q_ = Q.replace("variable", p) # set the wanted variable
    
    sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
    sparql.setQuery(PREFIXES + Q_)
    sparql.setReturnFormat(JSON)
    sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
    results3 = sparql.query().convert()

    vars = results3['head']['vars']
    result = results3["results"]["bindings"][0]["result"]["value"] 
    print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
    temp=JSON2Pandas(results3)
    authors=pd.concat([authors,temp])

# %%
authors.index=personvars
authors=authors.sort_values(by="result", ascending=False).astype(float).round(4)
authors

# %%
#authors= pd.DataFrame.from_dict(personstats,"index", columns=["hasValue"]).sort_values(by="hasValue", ascending=False).astype(float).round(4)
pd.concat([authors,people], axis=1).rename(columns = {'result':'authors', 'resultfi':'authorsFin',"hasValue":"allPeople"})#, inplace = True)#, keys=["authors","all"])

# %%
# so, it is safe to draw conclusions about the mother tongue, gender or nationality, but other info is less documented

# %%
# then just count all people, all authors and Finnish authors
Q = """ 
SELECT (COUNT(DISTINCT ?anyperson) AS ?totalPeople)  (COUNT(DISTINCT ?person) AS ?authors)  (COUNT(DISTINCT ?personfi) AS ?finnishAuthors) 
    WHERE

{
  {
    # ?anyperson a foaf:Person . # all people
  }
 UNION
    {
    # ?person a foaf:Person . # all people
    # ?person kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> . # kirjailijat
    }
    UNION
    {
      # ?personfi a foaf:Person . # all people
    # ?personfi kaunokki:occupation/skos:broader* <http://www.yso.fi/onto/koko/p35732> .# kirjailijat
      # ?personfi kaunokki:kansallisuus <http://www.yso.fi/onto/koko/p35259>.
    
    }
    
  }


"""


sparql = SPARQLWrapper("http://ldf.fi/booksampo-2022/sparql")
sparql.setQuery(PREFIXES + Q)
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader(*list(AUTHORIZATION_HEADER.items())[0])
results3 = sparql.query().convert()

vars = results3['head']['vars']
#result = results3["results"]["bindings"][0]["result"]["value"] 
print("Query returned {} result:".format(len(results3["results"]["bindings"])), result)
JSON2Pandas(results3)
